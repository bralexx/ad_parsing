# %%
# !pip install openai --quiet
# !pip install tiktoken --quiet

# %%
from google.colab import drive
drive.mount("/data")
# Out:
# Mounted at /data

# %%
cd /data/MyDrive/Dataset
# Out:
# /data/MyDrive/Dataset

# %%
import numpy as np
import pandas as pd
import re

import json
from tqdm.notebook import tqdm

import openai
import tiktoken

# %%
np.random.seed(1337)

# %% [markdown]
#  ## Данные

# %%
data = pd.read_csv("merged_final.csv")
print(data.shape)
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data = pd.read_csv("merged_final.csv")
#       2 print(data.shape)
#       3 data.head()
#
# File /mnt/d/documents/univer/ad_parsing/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /mnt/d/documents/univer/ad_parsing/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /mnt/d/documents/univer/ad_parsing/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /mnt/d/documents/univer/ad_parsing/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /mnt/d/documents/univer/ad_parsing/.venv/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'merged_final.csv'

# %%
data.drop_duplicates(subset=["Text"], inplace=True)
print(data.shape)
data.head()
# Out:
# (94611, 4)
#                                                 Text      WallId  PostId  \
# 0  iРhonе 11 64гб в крacном цвeте с ЧЕКОM из магa...  -151775338  537819
# 1  Kx-tca285\nБ/у недолго. В рабочем состоянии, н...   -48332904  704790
# 2  🌹ПОЛУЧИЛИ ДАЧНИ КОСТЮМ \n🌹КАЧЕСТВО СУПЕР \n🌹РА...  -192083416   12439
# 3  Продам 1000р. Размер 46. (В идеальном состояни...   -90442795  349691
# 4  мини-сумка charles&keith яичного цвета. новая....  1332882905  429778
#
#   Source
# 0     vk
# 1     vk
# 2     vk
# 3     vk
# 4     tg

# %%
# data_20k = data.sample(n=20000)
data_20k = pd.read_csv('data_20k.csv')
print(data_20k.shape)
data_20k.head()
# Out:
# (20000, 4)
#                                                 Text      WallId  PostId  \
# 0  б/у:\n∙ сумка дорожная на колесах (~высота 70с...  1332882905  570967
# 1  davines - мусс-объем \nthis is a volume boosti...  1332882905  618057
# 2  👌Новая поступления  🥳🥳🥳\n.     tencel \n     Ц...  -192083416   13589
# 3  клининг/фея чистоты/ уборка 🧚\nофис, квартира,...  1121942433  400700
# 4  Распродажа \nЦена: 550р шт \nРазмер: 41.42.43....  -206817857   82815
#
#   Source
# 0     tg
# 1     tg
# 2     vk
# 3     tg
# 4     vk

# %%
data_20k["Source"].value_counts()
# Out:
# Source
# tg    10548
# vk     9452
# Name: count, dtype: int64

# %%
data_20k.isna().sum()
# Out:
# Text      0
# WallId    0
# PostId    0
# Source    0
# dtype: int64

# %%
data_20k.to_csv("data_20k.csv", index=False)

# %% [markdown]
# ## Constants

# %%
model = "gpt-4-turbo-2024-04-09"

# %%
import os
token = os.getenv('DIPLOMA_OPENAI_API_KEY')
# with open("../ChatGPT/TestPrompts/openai.txt", "r") as file:
#     token = file.readline().strip()

# %%
prompt = """You are an AI trainer at a marketplace company. Your role is to convert product offer posts from plain text into structured JSON format. A "bundle" is defined as a set of items being sold together, which cannot be separated.
The JSON structure must include:
"place": The location where the buyer can pick up the product or delivery information, if available.
"bundles": A list of dictionaries, each representing a valid bundle.
Each bundle dictionary should contain ONLY the following information for ONE bundle:
"name" (string): A brief title of the bundle, including enough details for the customer to understand what is being sold. Ensure to include important general details, such as product category, if provided.
"quantity" (string): The minimal unseparable amount of product in the bundle. For countable items, this is the number of items. For non-countable products (like liquids or materials), this should reflect the volume, length, or other relevant metrics (default is '1').
"price" (number): The cost for the entire bundle, based on the 'quantity' specified.
"currency" (string): The currency for the 'price' (default is 'RUB').

Regarding product variations, such as size or color, these should NOT be treated as separate bundles. Variations should be considered additional descriptions and are not required in the JSON. The focus is on distinct products or bundles as defined by their essential characteristics, not their variations.
Exclude any fields with null values from the JSON. Do not add descriptions or any fields other than those specified. If no price information is provided, exclude the bundle from the JSON. Answer in the language of the original offer.
Your response should be a JSON only, with no additional text required.
"""

# %% [markdown]
# ## Functions

# %%
def count_tokens(text):
    encoding = tiktoken.encoding_for_model(model)
    return len(encoding.encode(text))

# %%
client = openai.OpenAI(api_key=token)

# %%
class OpenAIMarkup:
    def __init__(self, openai_client, model, prompt, checkpoint_frequency=200):
        self.client = openai_client
        self.model = model
        self.prompt = prompt
        self.checkpoint_frequency = checkpoint_frequency
        self.save_data = None

    def process_ad(self, text):
        return self.client.chat.completions.create(
            messages=[
                {"role": "system", "content": self.prompt},
                {"role": "user", "content": text},
            ],
            model=self.model,
        ).choices[0].message.content

    def save_checkpoint(self, dataset, responses, save_path):
        self.save_data = dataset.iloc[:len(responses), :].copy()
        self.save_data["GptResponse"] = responses
        self.save_data.to_csv(save_path, index=False)

    def markup_dataset(self, dataset, text_column="Text", limit=10000, save_path="final_labeled.csv"):
        json_responses = []
        save_data = None
        failed = 0
        for i, ind in tqdm(enumerate(dataset.index)):
            try:
                json_response = self.process_ad(dataset.loc[ind, text_column])
            except Exception as e:
                print(f"Failed to process ad: '{dataset.loc[ind, text_column]}'")
                failed += 1
                continue
            json_responses.append(json_response)

            if i % self.checkpoint_frequency == 0:
                self.save_checkpoint(dataset, json_responses, save_path)
                print(f"checkpoint of size {self.save_data.shape} saved!")

            if i - failed >= limit:
                break

        self.save_checkpoint(dataset, json_responses, save_path)
        return self.save_data

# %% [markdown]
# ## Small test

# %%
markupper = OpenAIMarkup(client, model, prompt, 1)

test_data = pd.DataFrame({
    "text": [
        "все футболки в идеальном  состоянии  все оригинальные цена одной футболки 40 лари  . 1. levi’s  ( размер м ) 2. lyle scott ( размер m ) 3. the north face ( размер xl ) 4. lyle scott ( новая размер м ) 5. lyle scott ( размер s ) 6. new balance ( размер l )  7. nike ( размер l )  8. tommy hilfiger ( размер м ) 9. nike ( размер l ) 10. nike ( размер xl )",
        "книги на английском  blue moon 4€ the good fight 5€ the book thief 4€ the pillars of the earth 4€ peaky blinders 5€ all the light we cannot see 5€ the last letter from your lover 5€ this is going to hurt в твердой обложке 9€ самовывоз пафос, юниверсал",
        "Распродажа Цена: 350р Размер:104-110- 116-122-128 Без выбора цвета Арт: 1-4-10 корпус А",
    ] * 10
})

test_result = markupper.markup_dataset(test_data, text_column="text", limit=3, save_path="test_markup.csv")
# Out:
# 0it [00:00, ?it/s]
# checkpoint of size (1, 2) saved!
# checkpoint of size (2, 2) saved!
# checkpoint of size (3, 2) saved!
# checkpoint of size (4, 2) saved!

# %%
test_result.head()
# Out:
#                                                 text  \
# 0  все футболки в идеальном  состоянии  все ориги...
# 1  книги на английском  blue moon 4€ the good fig...
# 2  Распродажа Цена: 350р Размер:104-110- 116-122-...
# 3  все футболки в идеальном  состоянии  все ориги...
#
#                                          GptResponse
# 0  {\n  "place": "Georgia",\n  "bundles": [\n    ...
# 1  {\n  "place": "самовывоз пафос, юниверсал",\n ...
# 2  {\n  "place": "Арт: 1-4-10 корпус А",\n  "bund...
# 3  {\n  "place": null,\n  "bundles": [\n    {\n  ...

# %% [markdown]
# ## Финальная разметка

# %%
markupper = OpenAIMarkup(client, model, prompt, checkpoint_frequency=200)
labeled_data = markupper.markup_dataset(data_20k.iloc[5000:10000], text_column="Text", limit=5000, save_path="additional_labeling_checkpoint.csv")
# Out:
# 0it [00:00, ?it/s]
# checkpoint of size (1, 5) saved!
# checkpoint of size (201, 5) saved!
# checkpoint of size (401, 5) saved!
# checkpoint of size (601, 5) saved!
# checkpoint of size (801, 5) saved!
# checkpoint of size (1001, 5) saved!
# checkpoint of size (1201, 5) saved!
# checkpoint of size (1401, 5) saved!
# checkpoint of size (1601, 5) saved!
# checkpoint of size (1801, 5) saved!
# checkpoint of size (2001, 5) saved!
# checkpoint of size (2201, 5) saved!
# checkpoint of size (2401, 5) saved!
# checkpoint of size (2601, 5) saved!
# checkpoint of size (2801, 5) saved!
# checkpoint of size (3001, 5) saved!
# checkpoint of size (3201, 5) saved!
# checkpoint of size (3401, 5) saved!
# Failed to process ad: 'новая канва из тайгера
#
# 1) большая 65 на 90см -8 евро
# 2) маленькая 40 на 50см-  4 евро
#
# 2 за 10 евро )
# пафос'
# Failed to process ad: 'продаю свой муз стаф: 1) электрогитара fender mexican stratocaster. состояние идеальное. звук характерный фендеру. установлен тремсеттер. 750 евро.
# 2) усилитель marshall dsl20 ламповый отличное состояние. 320 евро.
# 3) кабинет blackstar 16 ом. отличное состояние 130 евро.
# все в лимасоле. можно послушать/проверить.'
# Failed to process ad: 'большие 2 корзины за обе 8 евро. лимассол'
# Failed to process ad: 'вечернее поате 48 размера 65 лари .писать в лс'
# Failed to process ad: 'МОУ,,Средняя общеобразовательная школа 9 им.К.К.Рокоссовского,, на постоянную работу требуются уборщики служебных помещений.Оформление по ТК.Телефон 8(47148)3-42-25'
# Failed to process ad: 'Распродажа
# Размер: 40-42-44-46-48-50
# Цена: 100р
# Размер: 52-54-56-58-60
# Цена: 150р
# Без выбора цвета
# Арт: 28-82'
# Failed to process ad: 'продам кроссовки женские pierre cardin
# размер 38
# цвет молочный.
# цена 45 gel
# м исани'
# Failed to process ad: 'Итальянские, замшевые, весенние сапоги, 36 размер, стоимость 1000 руб.'
# Failed to process ad: '92 размер весна-осень 1000 руб.'
# Failed to process ad: 'Продам honor 8x на 128гб
# Состояние хорошее остальное в личку
# Комплект зарядка, коробку порвала дочка
# Телефон работает отлично все как надо и отпечаток тоже
# Любые проверки
# Цена 5300'
# Failed to process ad: 'yeezy 450 sulfur 10.5 us (на ваш реальный 9.5us), состояние новых - одевал два раза. 180 usd(t)/470 gel'
# Failed to process ad: '#БНИ_ПродамБУ_Москва
# #БНИ_Почта
# #БНИ_Boxberry
# #БНИ_авито
# #БНИ_alexanderzhiganov
#
# 1) Champions of Hara + Chaos on Hara - доп в пленке, у базы немного помялся один угол при транспортировке - 12000
# 2) Sorcerer + Virgiliu Character Pack + Sylvanei Lineage Pack + Bloodsoaked Fjord Domain Pack - 5000
# 3) Королевские Хроники Полное Издание - одна партия - 2800
# 3) Village Rails - 2000
# 4) Voluspa - тайлы потерлись от времени - 1400
# 5) Новые Римляне - 800
# 6) Betrayal Legacy - пройдена половина кампании, какие-то компоненты испорчены (наклейки, надписи); что-то можно обратить, можно играть дальше, можно играть как в обычный улучшенный Betrayal (есть режим вне кампании) - 1000'
# Failed to process ad: 'Распродажа
# Цена: 400р
# Ткань: Ангора
# Размеры: 44,46,48,50,52,54
# АРТ: 27-63
# https://vk.com/id575629904'
# Failed to process ad: 'продам вечернее платье, надела один раз на новый год) размер m-s, состоит из мелких черных пайеток. отдам за 70 лар'
# Failed to process ad: 'умные свичи для наружных жалюзей, работают с алексой. 2 шт 30 евро'
# Failed to process ad: 'playstation 4 + 3 джойстика и куча игр
#
# цена: 650 gel (либо соответствующая сумма в рублях)
#
# открыт к разумному торгу (можете писать вашу цену в лс)
#
# продаю свою playstation в идеальном состоянии. вместе с ней отдам 3 джойстика – два обычных и один razer raiju (сам по себе стоит в районе 250 gel) + hdmi кабель, чтобы можно было сразу начать играть. помимо этого, на playstation куча аккаунтов с играми, среди которых
#
# - the last of us part 2
# - teenage mutant ninja turtles: shredder's revenge
# - it takes two
# - a way out
# - tomb raider: definitive edition (все 3 игры)
# - cuphead (+ dlc)
# - the walking dead: the telltale definitive series
# - lego star wars: the skywalker saga
# - stray
# - doom eternal
#
# готов договориться о встрече, так же можем договориться о том, чтобы вы могли все проверить на работоспособность.'
# Failed to process ad: 'Щеночки все мальчики живут на дачах, дачники очень не довольны таким соседством, грозят отравить. На вид месяцев пять . Будут не большие, коротколапые. Может кому понравятся мальчишки и вы захотите спасти звоните 89038702124. Им там не выжить . Находятся в Курской области. Поможем с доставкой.'
# Failed to process ad: 'nespresso machine latisima touch silver, лимассол, 200€
# в отличном состоянии, без царапин.'
# Failed to process ad: 'арабский парфюм lattafa
# " confidential" новый ,
# 30€
# никосия'
# Failed to process ad: 'Распродажа
# Комплект из трёх полотенец.
# Цена: 400р. без выбора
# Размер:
# 70*130- 1 шт.
# 50*80-1 шт.
# 40*70-1шт.
# Состав: 100% хлопок.
# Материал: Махра.
# Плотность 400 гм/2.
# Арт 2Д-62 корпус Б
# https://vk.com/labazin_ru'
# Failed to process ad: 'Полка - 50р или шоколадка
# Тубус - аналогично
# Мультиварка -1000р
# Забирать в 11ке'
# Failed to process ad: 'Кофемашина Nivona 525
#
# Базовая модель от одной из трех топовых производителей высокоранговых 💎кофемашин (Nivona, Jura, Melitta). Это версия с красивым титановым корпусом (+50€) вместо обычного черного🥰
# Nivona - швейцарский бренд, модель 525 производится в Португалии. Кофемашина в отличном состоянии, использовалась бережно, вовремя обслуживлась.
#
# Отдаю с двумя новыми supply кофе от тейсти кофе и жидкостью для удаления накипи за 28700
# Сейчас новая на Маркете стоит 47000
# 13,14 общежития или самовывоз из 13ки
#
# Все вопросы и предложения в ЛС'
# Failed to process ad: 'привет. продам личные вещи в связи с переездом. сюда все не влезет, больше вещей у меня в канале, ссылку дам в личку
#
# • стол рабочий с выдвижным ящиком
#
# рабочая поверхность 69х99 см
# высота 75 см
# выдвижной ящик 41х33 см
#
# состояние нового.
#
# цена - 150 лари, торг
#
# • стильная беспроводная клавиатура miiw (mwbk01) розового цвета. режимы bluetooth/беспроводной usb, mac/windows
#
# причина продажи - сложно привыкнуть к низкопрофильной клавиатуре. цена новой в магазине - 200 лари
#
# цена: 100 лари
#
# • сумка кожаная, состояние идеальное
#
# цена: 100 лари
#
# стильный купальник светло-горчичного цвета в идеальном состоянии.
# надевался лишь раз для примерки
#
# размер s
#
# цена: 150 лари'
# Failed to process ad: 'подарю тренировочные футы (самбо, дзюдо, тхэквондо). не новые, но в отличном состоянии. размер 38-39. никосия.'
# Failed to process ad: 'очки bershka
# очки mango
# очки -0,75
#
# 20 лари любые.'
# Failed to process ad: 'Ниблер, новый. 100₽
# Ртс'
# Failed to process ad: 'добрый день. продаю стеллаж. заберёте сегодня - отдам за 130.'
# Failed to process ad: 'Арт.07002 набор профессиональный в сумке, 15шт поставляется в органайзере из полиэстера Общий вес набора в упаковке - 3,6кг
# В набор входит:
# Стриппер СИ-6М
# Кабелерез 160 мм
# Кусачки боковые 160 мм
# Круглогубцы 160 мм
# Отвёртка 4.0x100 мм 1000В
# Отвёртка 5.5x125 мм 1000В
# Отвёртка 6.5*1.2х150 мм 1000В
# Отвёртка PH0x75 мм 1000В
# Отвёртка PH1x100 мм 1000В
# Отвёртка PH2x125 мм 1000В
# Тестер напряжения ТН-3
# Саквояж монтажника универсальный
# Пассатижи 180 мм
# Отвёртка 5.0x100 мм
# Отвёртка 6.5x125 мм
# Отвёртка PH2x125 мм.
# Гарантия производителя.
# Есть и другие инструменты. См. Профиль'
# Failed to process ad: '1. Подставки под ноутбук икеа, 2 шт. по 200 каждая.
# 2. Настольная игра Индустрия, почти новая, все элементы на месте, 1200.
# Забирать на Дирижабельной 13 или по договорённости на кампусе.'
# Failed to process ad: 'Чайник Kraft, в отличном состоянии, забирать из 8ки (могу принести в общагу по кампусу)
# 1,5к'
# Failed to process ad: 'Толстовки на флис
# Цена 550р
# Распродажа
# Размер 50 52 54 56 58 60
# Без выбор цвет
# Тц Корпус А 2д-38
# https://vk.com/d.saidov1988'
# Failed to process ad: 'Продаю коляску 2в1 в хорошем состоянии. Удобная в передвижение. Прогулочный блок можно менять лицом к себе или от себя.Регулируется ручка по высоте. Сумка,подстаканник в комплекте. 8000 руб. Дмитров. Самовывоз'
# Failed to process ad: '•продаю кофту оверсайз размера xs, фирмы shein😁
# •цена: 450 рублей)
# •можно личной встречей на моем метро, за дп приеду на Ваше метро, либо почтой за Ваш счет, при личной встрече возможна примерка
# •писать в личные сообщения🥰'
# Failed to process ad: 'продам монитор acer nitro vg240ybmipx, 1920x1080, 75 гц, ips, 24”
#
# состояние идеальное, без сколов и царапин, при покупке проверялся на битые пиксели, обнаружено ноль штук)
# коробки нет, но остался пенопласт для безопасной транспортировки.
# кабель питая и провод hdmi на месте.
#
# цена: 300 лар (торга нет)
# самовывоз: элизбара миндели'
# Failed to process ad: '‼️‼️Продам коляску MAYA
# VERDI BABIES с переноской за 1500 пишите в личку.
# Город Дмитров‼️‼️'
# Failed to process ad: 'devotchkarita нарушил правила чата и не сможет писать до 24.09.2023 22:05:39. правила чатов'
# Failed to process ad: 'Монитор hp (5000 р)'
# Failed to process ad: 'Распродажа
# Штаны теплые на флисе
# Размер: 44-46-48-50-52-54-56-58-60
# Цена: 400р на 50раз.
# Цена: 350р
# Без выбора цвета
# Арт: 2Д-94 корпус Б
#  https://vk.com/anas_tjo'
# Failed to process ad: 'Цена: 500р
# распродажа
# Размеры: 50,52
# без выбора цвета
# линия 24 павильон 53'
# Failed to process ad: 'Слипоны Vans желтого цвета, по сантиметрам, 24.5 Унисекс модель, можете посмотреть ещё раз размеры на язычке, его фото в галерее. Состояние приближенное к новым, носили три раза для походов до магазина. Новые покупались за 6000 примерно. Отдам за 2000₽ без торга
# Метро Перово. Забирать прямо у него'
# Failed to process ad: 'серьги бижутерия высокого качества 15 лари територииально сабуртало'
# Failed to process ad: 'Продаём электрический чайник Starwind!
# Служил нам верой и правдой всего полгода (продаём в связи с переездом).
# Воду греет отлично, объём 1,7 л (чего более чем достаточно для чайных посиделок с соседями). Не занимает много места, смотрится стильно модно молодёжно (пластиковый корпус).
# Цена вопроса—1000 рублей, забирать из 8-ки, но при необходимости можем принести куда-то на кампус.'
# Failed to process ad: 'оригинальные часы. куплены в европе. все работает, ударов не было, носились раз 5 максимум. коробки к сожалению нет. 250€'
# Failed to process ad: 'crocs 39-40
# надевала 1 раз, не подошел размер, привезли из гонконга
# 150 лари'
# Failed to process ad: 'стойка для телевизора, чтобы катать его из комнаты в комнату и смотреть нетфликс не только в зале, но и в кроватке, или на балконе.
#
# 100 €'
# Failed to process ad: 'Распродажа
# Щетки для ресниц 50шт
# Цена: 99р
# Арт: 2а-40 корпус Б'
# Failed to process ad: 'Требуются модели на
# ✅Тотал Блонд
# ✅Airtouch(для уточнения стоимости,фото волос в ЛС⬇
# ✅Работаю на премии косметике
# ✅Территориально м.Университет
# ✅Волосы строго не чёрные, без хны и басмы
# W.app https://wa.me/+79215649313
# Vk мои работы https://vk.com/id817486092'
# Failed to process ad: 'Матрас 200×90, год бережной эксплуатации, покупался за 7к
#
# 5500₽, возможен торг'
# Failed to process ad: 'кастрюля ikea с крышкой
#
# 15 gel, ваке. можно доставкой курьером
#
# только сегодня, завтра уезжаем, не влезло в багаж.'
# Failed to process ad: 'плошка с кактусами, один из них (astrophytum asterias superkabuto star shape) на ebay продается по цене всей плошки, а на кипре его вообще не найти. ширина плошки 17 см. пафос, 25 евро. дам подробные рекомендации по уходу.'
# Failed to process ad: 'Распродажа
# Цена: 79руб.
# Арт: 6-21'
# Failed to process ad: 'xbox wireless controller
#
# 110 лари'
# Failed to process ad: 'продам:
#
# 1)instax mini 11 - 240 лари
# 2)instax wide 210 - 140 лари
# оба исправно работают, нет никаких проблем. коробок нет.
# так-же есть картриджи на них
# - картридж на mini(2шт) 30лари/шт
# - картридж на wide(2шт) 35 лари/шт
#
# 3) клавиатура беспроводная logitech k380 белая. удобная тихая клавиатура. залипает клавиша вправо. в использовании больше года.
# 50лари.
#
# 4) клавиатура механическая беспроводная reddragon белая с подстветкой. в использовании недолго. заряжал 2 раза всего. заряжается через usb-c.
# подключается через адаптер или bluetooth.
# 110лари.
#
# 5)2 переходника sata ssd - ssd m2. + салазки для 3.5
# 15 лари.
#
# 6) док-станция и повербанк с беспроводной зарядкой 2в1. usb-a + usb-c. 10000mah.
# фактически новый. разрядил один раз. был куплен месяц назад.
# 50 лари.'
# Failed to process ad: 'Продам лавку для жима, б/у. 3000руб.'
# Failed to process ad: 'продаётся когтерезка для кошек и собак, новая. 10 евро. лимассол'
# Failed to process ad: 'посудомоечная машина
# (посудомойка)
# delonghi ddw60x20
#
# цена 450€
# лимасол, каника
#
# три яруса, сама открывается после мойки
# в использование полгода(гарантийные документы в наличии), продаем в связи с переездом'
# Failed to process ad: 'кожаные штаны, buse.  очень толстая кожа, состояние идеальное. размер примерно 31 в талии 30 лари'
# Failed to process ad: 'Распродажа
# Полотенца
# Цена: 200р
# Цена с выбором 250
# Размер:   80на80  см
# Арт: 2Б-40 корпус А'
# Failed to process ad: 'продам утюжок (выпрямитель) для волос babyliss керамический. пользовалась 1 раз, состояние идеальное. 35 евро. лимассол'
# Failed to process ad: '5000р'
# Failed to process ad: 'щётка на робот пылесос xiaomi mi robot vacuum mcp essential.
# абсолютно новая. не угадала с моделью.
# 10€
# лимассол, район эра аполлон.'
# Failed to process ad: '❗Apple watch Series 8 45mm M\L, темная ночь❗
# Купил маме, не подумав о размере, хочу продать эти и купить 41мм.
# Не вскрывались, новые, пломбы на месте!
# куплены 21 февраля в DNS
# Цена - 36 000Р
# +79852352601
# Выручайте)
# ⚠'
# Failed to process ad: 'привет каждому
#
# пуловеры
# чистая шерсть:
# 🧶🐏серый с горлом size m•25₾
# 🧶🐏зеленый size m•25₾
# 🧶🐏черный size m•25₾
#
# футболки  / рубашки / худи
# 👕 серый худи  size м •25₾
# 👕 серая футболка с принтом  size м •20₾
# 👕 рубаха с принтом  size м •20₾
#
# нахожусь около метро 🚇 делиси (можно приехать на примерку), можно оформить доставку (+6₾ , но от 2ух вещей бесплатно) практически все унисекс
#
# ❤️продаю все, что указано в списке
# {мой рост 176}'
# Failed to process ad: 'motorola edge 2021 8/256 144inch ekran 108mp ultra pixel
#
#
# спешу очень
# быстрым сегодня будет скидка, отдам за 350 ❗️
#
# состояние видно на фотографиях, работает идеально, что касается громкости то отличный звук
#
# не лагает! батарею держит достаточно долго'
# Failed to process ad: 'друзья, добрый день, продаём качели, умельцы если починят одну перекладину, они смогут вас ещё долго радовать, в разборном состоянии, косяки на фото, самовывоз на сабуртало, 50 лари'
# Failed to process ad: 'кокосовое масло iherb 1,6л.
# использовала только 200 мл (сразу же перелила в маленькую баночку когда получила). остальное хранила в прохладном месте. продаю в связи с отъездом. 10€
# ларнака'
# Failed to process ad: 'Распродажа
# Визитница для карт
# Цена: 150р
# Арт: 2-2-21 корпус А'
# Failed to process ad: 'окарина 20 лар
#
# метро мед.университет'
# Failed to process ad: '🎁🎁🎁Получили гамаши
# _,_,_,_,_,_,_,_,_, с начёсом не скатываются ⚜⚜⚜⚜ хлопок тепло 🔝🔝🔝🔝 размер 44,46,48,50,52,54,56,58,60,62,64,66 ↔️↔️↔️ цена Упоковка 2040 ₽ (12×170 ) ⏭⏭⏭ цена за штуку 200 рублей 🔙🔙🔙 за качество гарантия ✅✅✅ место 2А-54 без ограничения
# Подробнее на https://vk.com/wall488363770_23944'
# Failed to process ad: 'продаю срочно! за такие чену только сегодня. кто сегодня берет дам ещё дешевле.
# темный стол с ящичками и боковым полкой - 300 лари
# большой бежевый стол - 350 лари
# куплено магазин в икеа, состояние прямо идеально.'
# Failed to process ad: 'Продам газовую плиту 5000 руб(4 года)'
# Failed to process ad: 'Здравствуйте!
# Весы для новорожденных momert 6400 - 1000 руб., пользовались всего несколько раз, надо будет только батарейку поменять;
# Сумка-переноска - 300 руб;
# Коврик игровой - 300 руб;
# Позиционер для сна новорожденных trelax, пользовались только длинной подушкой, остальное новое - 500 руб.'
# Failed to process ad: '1. клетка для хомяка
# 2. мини аквариум/ ваза
# 3. мотоцикл, есть дефекты( в личку отвечу в чем)
# 4,5 свечи
# 6. платье на 4-5 лет
# 7. стаканы
# 8. бокалы для шампанского
# 9,10. подушки из jysc 2 шт'
# Failed to process ad: 'книги minecraft 10 евро. никосия'
# Failed to process ad: 'микроволновка kenwood с функцией разморозки и много чего )) лимассол 50 евро
# доступно 11 июня утром !'
# Failed to process ad: 'фильтр midea с подогревом и охлаждением. в пользовании год. 180€
# лимасол каника'
# Failed to process ad: 'декоративная ваза, высота 85, ширина ок 40 см. 5 евро. пафос, тала'
# Failed to process ad: 'Свадебное платье
# 42-46
# 3.000
# В комплекте накидка кружевная и фата
#
# #одежда'
# Failed to process ad: 'Состояние хорошие.
# Цена за 1шт-500р
# Цена за 4 шт-1800р
# Метро. Волжская'
# Failed to process ad: 'продаю диван. красивая обивка - гобелен, кантри-стиль. состояние хорошее. немного расцарапана нижняя подушка (есть дополнительная ткань для ремонта).
# 75€
# лимассол.'
# Failed to process ad: 'Цена:650р
# Распродажа
# Ткань Турецкий лапша
# Размеры:50/52/54/56/58/60
# линия 27 павильон 83'
# Failed to process ad: 'босоножки liu jo 39 размер. торг уместен'
# Failed to process ad: 'Распродажа
# Цена: 400р
# Цена опт 6шт×380р
# Размер: 52-54-56-58-60-62
# Арт 2в 63 корпус Б
# https://vk.com/wall529483555_16021'
# Failed to process ad: 'Матрас Орматек Wellspring Plus, 80x200. Пользовалась им полгода.
#
# Забирать из 13 общежития
# Цена 2000'
# Failed to process ad: 'Ищу ребят кому нужна помощь.
# (Дам хорошую возможность)
#
# Ищу ребят кто хочет зарабатывать. Обязанности - обучиться, поработать пару часов в день, компьютер-телефон, интернет, быть на связи.
#
# Важно :
#
# - Платить не надо.
# - Покупать тоже ничего не надо.
#
# Если отложишь сейчас, можешь упустить шанс изменить свою жизнь.
#
# Чтобы начать, просто подпишись по ссылке: https://vk.cc/co5zRb'
# Failed to process ad: 'ПРОДАМ : 1 Куртка зимняя новая ,разм 52 - 1400 руб (фото1,2 ) ; 2 Куртка б/у , размер 54-56 : кожа натуральная в нормальном состоянии (прослужит еще не один год ) ,меховая подстежка (имеет потертости) , цегейковый воротник -1200 руб (фото 3,4 ) ; 3 Зимняя шапка (фуражка ) с отворотом новая , размер 57 - 200 руб (фото 5-8) ;4 Брюки классические размер 58 , длина 108 см , темно -синие , белорусского производста с содержанием шерсти - 1500 руб(фото 9) Обращайтесь в Л.С.'
# Failed to process ad: '🔥в грузии выступит стендап-комик александр незлобин!
#
# актер, телеведущий, юморист, режиссер, сценарист, а также продюсер и бывший участник comedy club вновь посетит грузию в рамках своего тура по странам мира. зрителям будет представлена новая программа!
#
# 📌17 октября — тбилиси
# театр имени а.с. грибоедова | 20:00
# билеты от 40 gel ➡️ здесь
#
# 📌18 октября — кутаиси
# eneik coworking | 20:00
# билеты от 50 gel ➡️ здесь
#
# подпишись 📱 @ads_ge'
# Failed to process ad: 'iphone se 2020 128gb. батарея 85%
# всегда в чехле и под стеклом. стекло сниму при осмотре.
# 650 лар'
# Failed to process ad: 'весы ,
# состояние отличное
# цена 15 евро
# никосия'
# Failed to process ad: 'новые,оригиналы,покупались на оф сайте,прогадали с размером
# модель унисекс
# 41 размер
# 160 лари'
# Failed to process ad: 'Сумка женская кожа 2500р.'
# Failed to process ad: 'Сапоги Paolo Conte.Осень/весна, в хорошем состоянии. По стельке 24см.Натуральная замша.
#
# Космонавтов
# В лс
# 1800р
#
# #БД_обувь'
# Failed to process ad: 'Продам джинсы мужские Bershka MAN размер 36, покупали год назад за 2500₽ носился один раз отдам за 1000₽, причина продажи лежит без надобности'
# Failed to process ad: 'Приветствуем Вас в студии дверей FOLK DOORS 🤓🤓🤓
#
#  ☑️МЕЖКОМНАТНЫЕ И ВХОДНЫЕ ДВЕРИ !!!
#
# ☑️СКРЫТЫЕ ДВЕРИ invisible от 1️⃣7️⃣9️⃣0️⃣0️⃣₽ за премиум комплект ‼️‼️‼️
#
# Уважаемые покупатели , мы занимаемся производством , продажей и установкой скрытых дверей invisible премиум класса. (усиленные) ‼️
#
# Мы не используем в производстве своих дверей дешевое сырье‼️
#
# Мдф 3мм и гофрокартон - это всё не к нам…
#  👉 К нам за качеством)‼️
#
# Для обвязки каркаса двери мы используем брус массив.
# Заполнение дверей деревянные рейки ‼️
# Облицовка МДФ повышенной плотности 6 мм.
#
# Грунт Италия в три слоя‼️
#
# И самое важное для обрамления дверей мы используем качественный врезной алюминиевый профиль-а не накладную алюминиевую кромку.-вы спросите а в чем разница?)
#
# ‼️ врезной профиль придает дополнительную жесткость полотну. (в отличии от накладной кромки)
#
# ‼️ врезной профиль толще, прочнее но при этом эстетически красив. Он не заползает на лицевую поверхность двери на 5-6 мм как кромка. Тем самым придает аккуратный и прочный торец двери.
#
# ‼️ так как профиль врезается в конструктив двери это предотвращает его отслоение при длительной эксплуатации.
# ​
# звоните уточняйте нужные Вам размеры.
# • двери в наличии в Москве
# • отгрузка в день обращения
# • замок и петли в комплекте
# • коробка и полотно имеют зарез под фурнитуру.
# • профессиональный монтаж
#
# Звоните или пишите нам на вотсап.
# • Двери межкомнатные скрытые Комплектация :
# Полотно грунтованное в два слоя ABS высотой 2000 мм
# Алюминиевая коробка потайного монтажа (комплект 2.5шт)
# Петли скрытой установки Италия Аgb 2.0- 2 шт.
# Замок wc магнитный-1шт.
# Цена комплекта на себя от 17.900₽‼️
# Цена комплекта от себя от 20.600₽‼️
#
#  В наличии полотна ABS высотой 2300 ‼️
#
# Звоните,пишите,прконсультируем Вас ‼️
#
#
#  Клиентам с ВК скидка 5% ‼️'
# Failed to process ad: 'продаётся 2 камеры видео наблюдения , 5 мигопикселей , разрешения фул ашди, wi-fi, трансформатор на 12 вольт, цена за штуку 100 лари'
# Failed to process ad: 'фильтр барьер 2 штуки в упаковке 40 лари'
# Failed to process ad: 'прожектор светодиодный  15€ г.пафос'
# Failed to process ad: 'Распродажа
# Тапочки
# Цена: 170р.
# Цена упк: 150р
# В упк: 6пар разные цвета
# Размер: 41-42-44-45-46
# Без выбора цвета
# АРТ: 2Г-84-86 корпус Б
# https://vk.com/id574588096'
# Failed to process ad: 'Размер 42. Рост не выше 173.
# Состояние отличное.
# Посадка высокая (на талии) .
# Расклешенные немного.
# Разрезы по бокам снизу.
# Stradivarius.
# 600 р.
# Метро ЦСКА.
# Писать в л.с.'
# Failed to process ad: 'Одеяло и подушки «натуральный шёлк»
# 🌿Размеры: Одеяла
# ✅1,5.       1100₽ 💸
# ✅2х.       1200₽ 💸
# ✅Евро.   1300₽💸
# 🌿Размеры: Подушки
# ✅50x70.  750₽💸
# ✅70x70.  850💸
# МЕСТО Тц Корпус А 2А-54 8 9267230720
# Подробнее на https://vk.com/wall488363770_23803'
# Failed to process ad: '3 евро за 3 штуки. лимасол, омония'
# Failed to process ad: 'Продаю стенку в комнату. Состояние отличное. Без царапин и сколов.
# Глубина, длина, высота указана в сантиметрах. Цена: 25.000₽
# Стол:
# Г 74
# Д 130
# В 75
# Полка над столом:
# Г 33
# Д 130
# В 64
# Тумба под телевизор:
# Г 49
# Д 95
# В 197
# Шкаф :
# Г 55
# Д 95
# В 197
# Комод:
# Г 35
# Д 95
# В 72
#
# Общая длина стенки без комода 320 см.'
# Failed to process ad: 'гриль 30е работает отлично. лимассол'
# Failed to process ad: 'продаётся новый гамак
# 30€
# лимассол
#
# продаётся напольная вешалка + вешалки
# 20€
# лимассол'
# Failed to process ad: 'керамический утюжок 65 лари, состояние нового'
# Failed to process ad: '6 евро за все ( круглый подсвечник дерево)
#
# лимассол'
# Failed to process ad: '#велосипед
# велосипед в отличном техническом состоянии . все исправно. рама l. цена 600 лари'
# Failed to process ad: 'пончо для сёрфинга, one size, большое, 25 евро, гермасоя'
# Failed to process ad: 'кувшин 1 литр 3€. лимассол'
# Failed to process ad: 'продам игровой контроллер для телефонов андроид.
# gamesir x2 pro xbox edition белый.
# абсолютно новая, нераспечатанная коробка.
# 100 евро. лимассол гермасойя.
# возможна отправка через acs или akis express.'
# Failed to process ad: 'проращиватель для зёрен 8 евро'
# Failed to process ad: 'продам iphone 6s plus. 16 gb. лимассол. 200 евро. полный комплект.
#
# ещё есть iphone xr 128gb белый. 500 евро. все в хороших состояниях'
# Failed to process ad: 'Распродажа
# Цена: 200р
# Цена уп 10*180р
# Ткань: хлопок
# Размер единый 44 46 48 50 52 54 56
# Арт: 2В-10 Корпус Б
# https://vk.com/dinhnguon01'
# Failed to process ad: 'Куртки женские
# Фабричный Китай
# Размер 42:44:46:48:50
# Цена :2100 рублей
# Идёт в размер
# Качество очень хорошое
# Место 2В-84.Корпус.  А
# Заказ ватсап -89261611199.   Бахтиёр'
# Failed to process ad: 'шуруповерт einhell в исправном состоянии!к сожалению нет зарядной станции (случайно выбросили )лимасол полимедия 20€ (цена оговаривается!)'
# Failed to process ad: 'продам компьютер в отличном состоянии
#
# toshiba hdwd120 2tb
# intel core i5-6600
# 16gb ram
# nvidia geforce gtx 1060 6gb
# monitor samsung cf390 24 дюйма 60 гц fhd 1080i
# genius keyboard
# +
# ups (источник бесперебойного питания)
#
# монитор, клавиатура, ups, корпус системного блока, кулеры и процессор куплены пару месяцев назад.
#
#
# все за 2000 лари'
# Failed to process ad: 'спальник deuter dreamlite 500. идеальное состояние, использовался не больше 5 раз. суперлегкий, до +10 градусов.
# 120 лари'
# Failed to process ad: 'Комбинезон Зима р 68
# Очень тёплый
# Ручки ножки закрываются, капюшон утягивается , есть мех  на капюшоне
# Малышке в нем тепло и комфортно !
# Состояние отличное !
# Цена 1000р
# Дмитров
#
# #детское'
# Failed to process ad: 'Полка продам, икша
# 1000р
#
# #мебель'
# Failed to process ad: '1. поло с удлинённым рукавом tommy hilfiger, женский xl, но подойдёт и на мужской s, покрой унисекс. состояние отличное, оригинал. 40 лари
# 2. пиджачок дуохром, винтаж(!) есть катышки с внутренней стороны, но мне нечем почистить. поэтому 15лари. подойдёт и парням и девушкам.
# 3. боди, не носилось. мерилось на бельё(!).  размер м-л, но под джинсы как топ можно и на s. очень нежное. эластичное. 20 лари.
# 4. блузка готическая, подойдёт до s. очень крутая, низ/рукава полупрозрачные!  15 лари.'
# Failed to process ad: 'Распродажа
# Цена: 100р
# Размер: 98,104,110,116,122,128,143,140,146
# Без выбора
# Арт: 2А-47 Корпус Б
# https://vk.com/ekarate88'
# Failed to process ad: 'продаём пластинки. тут малая часть, все могу выслать в лс) они не очень редкие, но может кому-то что-то понравится
# продаём по 5 лари за шт, если возьмёте все, то по 2 лари'
# Failed to process ad: 'продаются офисные столы. цена 180 лари'
# Failed to process ad: 'Роник ищет любящих хозяев! 👪
# Ласковый, добродушный, любознательный паренёк – настоящее счастье для тех, кто любит котов.
# Для Роника нет ничего приятнее, чем обнять своего человека, тарахтеть ему песенки, рассказать, как сильно ждал его целый день с работы, как высматривал с подоконника в прохожих, пытаясь уловить знакомую походку.
#
# Роник жизнерадостный, доверчивый мальчуган, он не утратил ни любви, ни доверия к людям даже после того, что ему пришлось пережить. Малыша с братиком и мамой-кошкой совершенно случайно нашли в абсолютно пустом дачном поселке восьмого марта.
# В крайней степени истощения, едва в состоянии передвигаться, эта семья вышла навстречу людям. Домашняя, ласковая кошка привела своих малышей в надежде на помощь. Это было настоящим чудом, посёлок в зимнее время не жилой. Как они смогли выжить, никто не знает.
#
# Мы забрали всех, отвезли в ветклинику, выходили, откормили, сдали анализы. Никаких инфекций, абсолютно здоровая семья.
# Сейчас Роник уже привит и кастрирован. Он энергичный, самостоятельный котофей. В нём как будто запрятана батарейка: развлекает себя сам целыми днями, изучает что-то новое, охотится на разноцветных мышек, ловит и носит их, зажав в передних лапках, по инерции бежит на задних. Ему интересно всё на свете. Это тот котик, который будет смотреть с вами телевизор, готовить ужины, убираться в квартире, убаюкивать детей и проверять у них уроки. Во всех делах Роник будет рядышком.
#
# Но всё, что так любопытно и заманчиво, теряет свою привлекательность, если Роника позвать обниматься. Если ему можно понежиться в объятиях любимого человека, подставить пузико и щёчки, спинку и бочок, чтобы и тут погладили, и там, и везде. Он все свои игрушки бросает и мчится тарахтеть, если позвали. А пока бежит, кричит «Мя, мя, мя», сообщая, что слышит и со всех лап торопится.
# А ещё Роник дружит с собаками и очень их любит, даже спит на лежаночке вместе. Возможно, именно так и удалось его семье дожить до встречи с волонтёрами. Может быть, собаки помогали им с питанием, приносили что-нибудь с охоты.
#
# Не описать в полной мере, насколько Роник удивительный котик. С ним просто нужно познакомиться лично. Он очень умный, совсем как человек.
# К лотку и когтеточке приучен, аккуратный. Возраст примерно 1 годик.
# Чтобы забрать Роника в свою семью, позвоните его куратору:
# 📱+7(901)342-93-01 Оксана'
# Failed to process ad: 'продам. оригинал. knowing ( estee lauder). 75ml флакон. концентрация eau de perfume. 200лари.'
# Failed to process ad: 'продам:
# аккумуляторы dewalt (деволт) 12v 2ah, 2 штуки - 150 лари
# кейс dewalt t-stack от перфоратора - 100 лари
# кейс dewalt t-stack от шуруповерта - 100 лари.
# естественно, все оригинал, кейсы очень качественные, можно переделать под свои нужды.
#
# все абсолютно новое.'
# Failed to process ad: 'Распродажа
# Цена: 150р
# Без выбора цвета и модель
# Арт: 2-2-21 корпус А'
# Failed to process ad: 'Распродажа
# Антистресс мозги
# Цена: 50р шт
# В упк 12шт×40р=480р
# Арт: 7-106'
# Failed to process ad: 'xiaomi mi scooter pro 2
# пробег 400км
# 370 eur'
# Failed to process ad: 'Штаны мужскые
# Цена рознитца 200  р
# Цена оп 12× 180=2160р
# Распродажа
# Ткань трикотаж
# Размер 48,50,52,54,56,58,
# Цвета чёрный и тёмна серый
# Тц Корпус-А 2Б.23
# https://vk.com/zen_odezda_opt'
# Failed to process ad: 'эспандер - 10 лари.
#
# 💥 при покупке от 2х книг на каждую следующую скидка минус 5 лари
#
# 🔥государственная третьяковская галлерея - 30 лари
#
# - эрик берн - игры, в которые играют люди
# - джонатан эйг - рождение таблетки
# - лю чженьюнь - меня зовут лю юэцзинь
# - александр солженицын - в круге первом
# - т. великотная, в. берхман, и. зеленская - записки оставшейся в живых. блокадные дневники
# - алексей сальников - петровы в гриппе и вокруг него.
# - лю чженьюнь - я не пань цзиньлянь
# - лю чженьюнь - мобильник
# - фредрик бакман - вторая жизнь уве
# - вика дмитриева - это же любовь
# - джек лондон - мартин иден
# - современная вегетарианская кухня
#
# возможен торг 💸
#
# метро дидубе'
# Failed to process ad: 'бесплатно и срочно. крайний срок -вторник. но лучше быстрее. отдаем диван и 2 кресла. каркасы в порядке, нужно обновить обивку, подушки. монагри (не монагрули!) самовывоз. матрасы продаются по 5 евро штука'
# Failed to process ad: 'тактические защитные баллистические очки не запотевающие, со сменным линзами очки предназначены для работы в экстремальных условиях, страйкбола, стрельбы, велоспорта, пляжного волейбола, вождения автомобиля, повседневного ношения и многого другого. у данной модели повышена характеристика антизапотевания, так же, благодаря мягкой вставке на линзах, очки полностью защищают глаза от пыли, песка и посторонних предметов.цена 80лари'
# Failed to process ad: 'автоматическое средство для уборки с пола пыли, волос, шерсти животных. как робопылесос, только не сосет! а собирает всю грязь на сменные тряпочки, сухая уборка. довольно тихий, за провода не цепляется. 10 евро.
# комплект тряпочек в подарок!
# лимассол'
# Failed to process ad: 'продам переходник для фотоаппарата с ef-m(eos) на ef/ef-s. пока доехал, я фотоаппарат продал. 150 лари'
# Failed to process ad: 'срочно!
# asus tuf gaming fx506i
# продам игровой ноутбук .
# брала 2,5 года назад для рабочих целей, до сих пор тянет отлично как высокую нагрузку от тяжелых программ, так и игры (спокойно играю в апекс, валорант, новый гарри поттер и человек паук на отлично).
#
# процессор
# amd ryzen 5 4600h (radeon graphics 3.00ghz)
# оперативная память
# 16 гб
# тип системы
# 64-разрядная операционная система,процессор
# ×64
# видеокарта
# nvidia geforce gtx
# 1650 ti
# (+amd radeon graphics)
#
# 700$ срочно
# 1800лари
# обоснованный торг'
# Failed to process ad: 'продается приставка ps4 pro версия на 500 гб памяти, в комплекте с 2мя джойстиками
# в отличном состоянии без царапин и повреждений
# цена: 570 лари'
# Failed to process ad: 'продаю дождевик превосходного качества salewa puez aqua 3
# крайне актуален в весенний сезон, устойчив к самым агрессивным погодным условиям. будет отличным подарком любителю активного отдыха! 🏔️
# к сожалению не угадал с размером при заказе.
# новый, размер l
#
# 265 лари'
# Failed to process ad: 'Ноутбук hp pavilion gaming laptop model 15-cx0027ur
# Состояние идеал
# Цена 40000 торг уместен'
# Failed to process ad: 'Распродажа
# Комплект постельное бельё
# Ткань:бязь
# Размер 1,5
# ️Пододельник 150Х210
# ️Простыня   150Х210
# ️Новинка   70Х70
# Цена 350 ₽
#
# Размер 2 спальный
# Пододельник 180Х210
# Простыня   180Х210
# ️Навлочка  70Х70
# Цена 400₽
#
# У нас можно бронь
# 8 926 723 07 20
# Подробнее на https://vk.com/wall488363770_22789'
# Failed to process ad: 'Ура распродажа 🌹🌹Нежнейшие туника   составить легкий и нежный образ♣️♣️♣️♣️
# —————————☘☘☘☘
# Цена -200₽ за штук 🤗🤗🤗
# Цвета без выбора
# —————————
# Размеры: 50,52,54,56,58,60 в размер
# Длина 100 см ☘☘
# Ткань 100% хлопок ☘☘'
# Failed to process ad: 'продается новый  столик для кофе 150 €'
# Failed to process ad: 'Серьги золотые вес 2.17г цена 11000 руб. Духи 30мл. Цена 1800 руб. Топик новый 75С цена 500 руб'
# Failed to process ad: 'Продам новый триммер 6000р (в работе не был'
# Failed to process ad: 'нарды и шахматы 50 лари электро шашлычница 100 лари фритюрница 65 лари'
# Failed to process ad: 'Чехлы на айфон 12 pro
# 1 шт - 150 рублей
# 6 шт отдам за 800 рублей
#
# #БД_айфон #БД_телефон'
# Failed to process ad: 'НОВИНКА  КУРТКА БАТАЛЬ
# Качество очень хорошее
# Цена за шт 1200₽
# Размер 48 50 52 54 56 58
# Размер в размер идут
# С капюшоном
# Подробнее на https://vk.com/wall488363770_22640'
# Failed to process ad: 'платье ликра, размер s - 30 лари
# глдани 2 микро.
# 574223871'
# Failed to process ad: 'продам. вторая часть русского языка немного повидала жизнь. все остальное в очень хорошем состоянии.
# м. церетели
# 35 лари'
# Failed to process ad: 'Распродажа
# Цена: 200р
# Размеры:
#  42,44,46,48,50,52,54,56,58,60
# 👉 С ВЫБОРОМ
# АРТ:2А-67 КОРПУС Б'
# Failed to process ad: 'Детские беспроводные наушники с ушками. Со встроенным микрофоном. Компактно складываются. Мигают при воспроизведении. 900р В наличии чёрные Пишите в личное сообщение'
# Failed to process ad: 'бижутерия по 5 лари, сабуртало'
# Failed to process ad: 'Градиёзная распродажа
# Healthy Sleep and Good Life
# 💥💥Новое поступление💥💥
#
# 🌹КОМПЛЕКТ ПОСТЕЛЬНОГО БЕЛЬЯ ОТ
# ФИРМА "Abbott" Б/В
# КАЧЕСТВО ЛЮКС 👌👌👌
#
# .         РАЗМЕР :1.5
# 🌹ПОДОДЕЯЛЬНИК.  150×220см. ( 1 )
# 🌹ПРОСТЫНЯ  150×220 ( 1 )
# 🌹НАВОЛОЧКА 70Х70.       ( 2 )
# 🌹ЦЕНА ЗА ШТУКУ 800₽
#
#
# 🌹РЕКОМЕНДАЦИИ ПО УХОДУ:
# 🌹СТИРКА ПРИ 40°С, БЕЗ ИСПОЛЪЗОВАНИЯ ХЛОРА.  ОТЖИМ ПРОИЗВОЪНЫЙ . ГЛАДИТЬ НА ВТОРОМ УРОВНЕ.
#
# WhatsApp для получении информации 8 926 723 07 20
#
# ПО АДРЕСУ 2A-54 КОРПУС А
# Подробнее на https://vk.com/wall488363770_23420'
# Failed to process ad: 'может у кого-то есть запасная затычка для подобного фитбола (обычно в комплекте идут 2-3 штуки), мы потеряли 🥲
#
# лимассол'
# Failed to process ad: 'продам такую б/у игровую мышь, коробка в комплекте, полный комплект, кроме чека, любые проверки, использовал около 3 месяцев. состояние как новая, цена 350 лари. самовывоз район диди дигоми'
# Failed to process ad: 'скакалка miniso sports 320см. никто не прыгал, оказалась слишком длинная.
# 🔅цена 10 лари
# 🔅самгори, московский проспект. могу передать у м.марджанишвили, руставели, либерти, авлабари'
# Failed to process ad: 'распродаю коллекцию настолок, могу отправить яндекс доставкой по тбилиси. пишите в личные сообщения, если есть вопросы, чтобы не потерять)
# 1 ark nova - 250 лари
# 2 not alone + дополнение not alone sanctuary (eng, 2-7 игроков) - 200 лари
# 3 santorini (eng, 2-4 игрока)- 150 лари
# 4 dune imperium (eng, 1-4 игроков) - 200 лари
# 5 root + дополнение the riverfolk (eng, 1-6 игроков) - 230 лари'
# Failed to process ad: 'Распродажа
# Тальк для депиляции
# Для всех типов кожи
# Цена: 150р
# Арт: 2-3-15 корпус А'
# Failed to process ad: 'Много 😻
# Отдам по 100₽/шт.'
# Failed to process ad: 'Цена: 300руб
# Распродажа
# Размеры: 48,50,52,54,56
# Без выбора цвета
# Линия 28 павильон 98'
# Failed to process ad: 'новый силиконовый чехол для iphone appel 12 mini. 35 euro. limassol'
# Failed to process ad: 'Распродажа
# Комплект постельного белья
# Ткань: бяз
# Цена: 350р Размер: 1.5сп
# Цена: 400р Размер: 2сп
# Двушка опт от 5шт цена: 370р
# Полутрка опт от 5шт цена: 330р
# Без выбора
# Арт: 2-1-18 корпус А'
# Failed to process ad: 'помпа для воды электрическая, с подсветкой, в комплекте провод для зарядки. состояние идеальное.
# 15 лари'
# Failed to process ad: 'Распродажа
# Карандаши 24 цвета-  заточенные, шестигранные, пластиковые, картонная упаковка
# Цена: 135р за 24 цвет
# Арт: Салют 2-3-05'
# Failed to process ad: 'пафос.
# корпус для пк. 25 евро. 2 месяца б/у.'
# Failed to process ad: 'продам два пылесоса mamibot exvac660 с функцией влажной уборки. цена за один 220 лари.'
# Failed to process ad: 'здравствуйте!
# продаю макбук про 2018 года
# параметры на фото
# в комплекте нет зарядного устройства
# цена 1500gel или 620$
# возможен торг
# состояние отличное'
# Failed to process ad: '💞💞💞💞💞💞💞💞💞💞💞
# 💥💥Новое поступление💥💥
# 🌹БЕЗ ВЫБОРА
#
# 🌹КОМПЛЕКТ ПОСТЕЛЬНОГО БЕЛЬЯ ОТ
# ФИРМА "ВЕНЕЦИЯ"
# КАЧЕСТВО ЛЮКС 👌👌👌
#
# .         РАЗМЕР :1.5
# 🌹ПОДОДЕЯЛЬНИК.  145×215см. ( 1 )
# 🌹ПРОСТЫНЯ  150×215 ( 1 )
# 🌹НАВОЛОЧКА 70Х70.       ( 2 )
# 🌹ЦЕНА ЗА ШТУКУ 600₽
#
#            РАЗМЕР : 2 КА
# 🌹ПОДОДЕЯЛЬНИК.   175×215.  ( 1 )
# 🌹ПРОСТЫНЯ  180×215  ( 1 )
# 🌹НАВОЛОЧКА 70Х70.  ( 2 )
# 🌹ЦЕНА ЗА ШТУК 650₽
#
#             РАЗМЕР : ЕВРО
# 🌹ПОДОДЕЯЛЬНИК    200×215 ( 1 )
# 🌹ПРОСТЫНЯ 240×215  ( 1 )
# 🌹НАВОЛОЧКА  70Х70 см  ( 2 )
# 🌹ЦЕНА ЗА ШТУК 750₽
#
#            РАЗМЕР  :  СЕМЕЙНЫЙ
# 🌹ПОДОДЕЯЛЬНИК 2 штук  145×215 см
# 🌹ПРОСТЫНЯ  240×215 см  ( 1 )
# 🌹НАВОЛОЧКА 70Х70 си.    ( 2 )
# 🌹ЦЕНА ЗА ШТУК 850₽
#
# 🌹ИНСТРУКЦИЯ ПО СТИРКЕ
# ИСПОЛЬЗОВАТЬ МОЮЩИЕ СРЕДСТВА ДЛЯ ЦВЕТНОГО БЕЛЬЯ. ПЕРЕД ПЕРВЫМ ИСПОЛЬЗОВАНИЕМ ПОСТИРАТЬ
#
# РУЧНАЯ ИЛИ МАШИННАЯ СТИРКА ПРИ ТЕМПЕРАТУРЕ НЕ ВЫШЕ З0 °С
# WhatsApp для получении информации 8 902 994 88 88
#
# ПО АДРЕСУ 2A-54 КОРПУС А
# Подробнее на https://vk.com/wall488363770_22451'
# Failed to process ad: 'продам компьютер. переезжаю.
# цена: 2900
#
# mboard: biostar b450mh rev. 6.3
# cpu: amd ryzen 5 5600 6 cores/12 threads/ 3.5-4.4ghz
# cooler: xilence xc025
# ram: 2x8gb 3200mhz 2rank
# graphic card: palit gamingpro rtx 3070ti
# ssd: kingston m2 snv2s 1tb
# power supply: xilence xn054 700w
# case: deepcool macube 110 bk (на стекле - пленка, не снимал при транспортировке, чтобы не коцать)
#
# в подарок отдам wifi адаптер, если кому-то нужен.м'
# Failed to process ad: 'Стол обеденный. Изготовлен на заказ. Массив очень тяжёлый.Натуральный дуб. Б/у
# Длина 128(208) разложенном виде)
# Ширина 82
# Высота 75
# Цена 12000
# Г. Москва, м Новогиреево'
# Failed to process ad: 'Куртки и пальто в хорошем качестве
# Дефект одной куртки указан на фото
# Синее пальто, зеленая куртка и бежевая-зимние
# Остальные демисезонные
# Размеры указаны на фото
# Любая за 500
# Метро теплый стан'
# Failed to process ad: 'Куртка для мужчин
# Цена: 500руб
# Распродажа
# Ткань:  эластан
# Размеры:  48-50-52-54-56
# Без выбора цвета
# Тц корпус А 1-2-20'
# Failed to process ad: 'подстаканник для колясок cybex состояние нового, не использовался. новый 30€. отдам за 15€. самовывоз лимассол.'
# Failed to process ad: 'iphone 14 plus (6,7 diagonal)
# как новый. 100% battery life
#
# 256gb
# лимассол
# 800е'
# Failed to process ad: 'Подвеска серебро. Цена 1.500 рублей
#
# Набор sokolov. Цена 1.500 рублей'
# Failed to process ad: 'Распродажа
# Кухонные весы с чашей до 3 кг.
# Цена: 350р
# Арт: 6-73'
# Failed to process ad: '💥💥Новое поступление💥💥
#
# 🌹КОМПЛЕКТ ПОСТЕЛЬНОГО БЕЛЬЯ
# 🌹ОТ ФИРМА "LOVELY"
# 🌹КАЧЕСТВО ЛЮКС ТКАНЬ ( ПОПЛИН )
#
# .         РАЗМЕР :1.5                            ПОДОДЕЯЛЬНИК150×220см. ( 1 )
# 🌹ПРОСТЫНЯ.             150×220 ( 1 )
# 🌹НАВОЛОЧКА.      70Х70.       ( 2 )
# 🌹ЦЕНА ЗА ШТУКУ 650₽
#
#            РАЗМЕР : 2 спальный
# 🌹ПОДОДЕЯЛЬНИК.   180×220.  ( 1 )
# 🌹ПРОСТЫНЯ   180×220  ( 1 )
# 🌹НАВОЛОЧКА 70Х70.  ( 2 )
# 🌹ЦЕНА ЗА ШТУК 750₽
#
#             РАЗМЕР : ЕВРО
# 🌹ПОДОДЕЯЛЬНИК  200×220( 1 )
# 🌹ПРОСТЫНЯ 220×240  ( 1 )
# 🌹НАВОЛОЧКА  70Х70 см  ( 2 )
# 🌹ЦЕНА ЗА ШТУК 850
#
#           РАЗМЕР Семейный
# 🌹ПОДОДЕЯЛЬНИК ( 2 ) 150×220СМ
# 🌹ПРОСТЫНЯ ( 1 ШТ  )  220Х240
# 🌹НАВОЛОЧКА ( 2 ШТ ) 70Х70 (±2) см
#
# 🌹ИЗДЕЛИЯ НЕ ОТБЕЛИВАТЬ ИЗДЕЛИЯ РАЗРЕШАЕТСЯ ГЛАДИТЬ ТОЛЬКО ТЕПЛЫМ УТЮГОМ
# .                                                                                                     ПРИ СТИРКЕ НЕ ИСПОЛЬЗОВАТЬ СРЕДСТВО СОДЕРЖАЩИЕ ОТБЕЛИВАТЕЛИ ХЛОР.
#
# РАЗРЕШЕНО ГЛАДИТЬ ПРИ МАКСИМАЛЬНОЙ ТЕМПЕРАТУРЕ 150°С
#
# 🌹БЕЗ ВЫБОРА ЦВЕТА
# Рисунки именно как на фото
#
# WhatsApp для получении информации 8 902 994 88 88
# Подробнее на https://vk.com/wall488363770_21909'
# Failed to process ad: 'Распродажа
# Носки детские
# Цена уп 12пар: 180р
# Размер: 12-15 15-20
# Арт: СТ4-122'
# Failed to process ad: 'производство япония , очистка и обогащение питьевой воды  в упаковки 2 карандаша , один открыли ,но не использовали , 10 евро лимассол бронь'
# Failed to process ad: 'Расходники для маникюра в хорошем состоянии, наполняемость 95%
# Цена за всё 1.500 рублей'
# Failed to process ad: '1. Блуза
#  Размер 42-44, покупала за 2599, продам за 800, состояние 5/5.
#
# 2. Платье
# Размер 42-44, покупала за 3000, продам за 1000, состояние 5/5
#
# 3. Платье
# Размер 40-44, покупала за 1500, продам за 800, состояние 5/5
#
# 4. Платье
# Размер 40-42, покупала за 4000, продам за 1800, состояние 5/5
#
# 5. Платье
# Размер 42-44, покупала за 2500, продам за 800, состояние 5/5
#
# 6. Футболка
# Размер 42-44, покупала за 1000, продаж за 500, состояние 5/5
#
# Метро Котельники'
# Failed to process ad: 'Платье, размер 42/44.
# Цена 2.500 рублей
#
# #БД_одежда'
# Failed to process ad: 'Шикарный флисовый костюмчик из тёплого и приятного к телу материала: худи + штанишки для комфортного отдыха!
# Ткань: Двусторонний флис
# Размеры: S,M
# Цена: 2000₽
# Цена опт 1700₽
# Подробнее на https://vk.com/wall488363770_22031'
# Failed to process ad: 'Летние вещи для девочки 4-5 лет.
# На рост 110. Туника и 4 платья.
# Все в идеальном состоянии.
# За все 1000₽.
# В подарок еще вещи: спортивные брючки 2 пары, два джемпера, футболки, маечка, шорты.'
# Failed to process ad: 'продаю обувь бренда ash 38 размер сапоги 80 лар и сникерсы 40 лар. самовывоз с метро руставели'
# Failed to process ad: 'Обмен на гель для стирки каждую вещь
# Кофта 152-158р
# Балетки 40 р
# Платье новое 164 р
#
# #БД_одежда'
# Failed to process ad: 'maison margiela dark blue size 44/45
#
# в идеальном состоянии  9/10
#
# цена 800 лари
#
# в магазине стоит 1900  лари'
# Failed to process ad: 'продам пк в сборе. почти не использовался. в идеальном состоянии покупал за 1400 лари весь набор. доту 2 тянет) танки не пробовали) самовывоз - дидубе улица самтредиа.
# цена: 850 лари
# пк, pc, стационарный компьютер'
# Failed to process ad: 'тушка кролика 2,5-3 кг. 15 евро за штуку. выращен на зёрнах. есть пару штук. лимассол'
# Failed to process ad: 'куртка mango man
# размер s / xs
# состояние 9/10
# цена 80 лари
# если заберёте сегодня, немного еще скину цену'
# Failed to process ad: 'Штаны Тонкий
# Цена 650руб
# Цена 600руб
# Распродажа
# Размер: 46-48-50-52-54-56
# Тц корпус Б 2г-84
# https://vk.com/id623711634'
# Failed to process ad: 'Распродажа
# Цена: 200р
# Цена уа 5×170р
# Ткань: х/б
# Размер. 128-134-140-146-152-158 см
# Арт: 26-05
# https://vk.com/club211867360'
# Failed to process ad: '🫧футболка. покупалась в малайзии, надевала 1-2 раза. укороченная, размер xs-s.
# за 35 лари🫶🏻30 лари'
# Failed to process ad: 'новые индийские коврики. один 5€, два 8€, три 10€ лимассол'
# Failed to process ad: 'грибы свежие, большое ведро 6 кг, 100 евро, лимассол'
# Failed to process ad: 'Распродажа
# Цена: 50р
# Размер:74-80-86-92-104-110-116-122-128-134-140-146-152
# Без выбора
# Арт: 26-56
# https://vk.com/artem2656'
# Failed to process ad: 'Цена: 200р
# распродажа
# Размеры: 46,48,ЕДИНЫЙ
# без выбора цвета
# Материал: прадо
# тц корпус Б-2Г-61'
# Failed to process ad: 'Фотоаппарат Вилли-авто начала 80-х 500р. С 80-х не эксплуатировался'
# Failed to process ad: 'Распродажа
# Цена: 450р
# Ткань: машинная вязка
# Размер : Единый 42 до 48
# Арт: 2-2-03 корпус А
# https://vk.com/kolianguyen'
# Failed to process ad: 'продается macbook pro 13.3
# intel core i7 16gb 512ssd
# cycle count 285
# на екране микро трешина как точка, не мешает не вчем  цене 1599л
# 597026978'
# Failed to process ad: '#БНИ_ПродамБУ_Санкт_Петербург
# #БНИ_ПродамБУ_Питер
# #БНИ_ПродамНовая_СПб
# #БНИ_ПродамБУ_СПб
# #БНИ_Авито
# #БНИ_wonderful_night
#
# Пришло время освобождать место под новые настолки. Продаю игры в отличном состоянии, если не указанного иного.
# 1. «Пригород» Suburbia - одна партия. 3900₽
# 2. Bloоdborne Forsaken cainhurst castle extra "Reiterpallasch Hunter" промо охотник (на английском) миниатюра, планшет и карта огнестрельного оружия. Новый - 2600₽
# 3. «О мышах и тайнах» 5 партий состояние коробки 3 из 5, состояние компонентов 4 из 5. Все миниатюры в любительском покрасе, все карты в протекторах, часть компонентов в миплхаус органайзере. 2900₽'
# Failed to process ad: 'геймпад (джойстик, контроллер) для xbox series s/x.
# состояние идеальное, покупал в апреле, использовал несколько раз.
# 180 лари
# тбилиси, сабуртало'
# Failed to process ad: 'Цена: 35.000
# Игровой пк GTX 1070 8g
#
# Брался год назад, все работает без нареканий. Никаких странных звуков нету
#
# ❗Видеокарта: GTX 1070
# ❗Процессор: AMD 5 2600 Six-Core Proccesor
# ❗RAM: 16gb
# ❗SSD: 512 GB
# ❗Блок питания: AeroCool VX PLUS 500w
#
# ✅21.5" Монитор ASUS VP229HE, 1920x1080, 75 Гц, IPS (меньше полу года)'
# Failed to process ad: 'столик-поднос икеа. 7 евро. лимассол'
# Failed to process ad: 'учебники в идеальном состоянии на 2 класс русской школы 50 евро'
# Failed to process ad: 'бронь. силиконовые формы высокого качества для пирожных, кексов и тарта итальянской фирмы silikomart. форма для тарта новая, остальные использовала 1 раз. 8 евро. лимассол ( парклейн)'
# Failed to process ad: 'для тех, кто любит яркие волосы))
#
# пигмент салатовый, банка заполнена больше, чем на 2/3
# при окрашивании получается, как на фото, цвет держится хорошо)
# также отдам осветлитель порошковый и кисточку для окрашивания.
#
# 15 лари'
# Failed to process ad: '1. Ортез на 1й палец кисти. Носила аккуратно, по несколько часов в день после растяжения, состояние нового. В Ортеке сейчас стоит >3к, отдам за 1к.
#
# 2. Футляр для украшений. Бу, но с функциональностью все хорошо. Очень удобный для поездок, тк компактный, вместительный и есть фиксирующие резинки.
# Отдам просто так или за шоколадку без сахара и фруктозы.
#
# 3. Бегония, крепкий куст, посаженный зимой, после тотальной обрезки неделю назад. Активно растёт, удобрен. Отдам за 250 или за 200 без горшка.
#
# 4. Черенки бегонии в подарок при любой покупке.
#
# 10ка, Долгопрудный.'
# Failed to process ad: 'Свитшот champion на флисе Абсолютно новый, с навесными бирками Оригинал! Любые проверки Размер женский M Если мужской то будет XS-S Короче на рост до 170 3к'
# Failed to process ad: 'Распродажа
# Контейнер для яиц в холодильник на дверцу на 30 штук пластик
# Цена: 350р
# Арт:  8- 24'
# Failed to process ad: 'Распродажа
# Очки женские
# Цена: 50р
# Арт: 2Д-11 корпус А'
# Failed to process ad: 'забирать недалеко от метро важа-пшавела. продажа в связи с переездом.
# фото 1 - новая - 8 лари.
# фото 2 - 3 - любая 4 лари.
# фото 4-5 - кастрюля для духовки. есть небольшой скол на крышке, но фото обозначила, пользовалась пару раз. цена - 8 лари.
# фото 6-7 тыквенный протеин из семян тыквы. попробовала 2 ложки и всё. сделано в августе. цена - 5 лари.
# фото 8 - семена черного кунжута - цена 4 лари.
# фото 9 семена чиа - 4 лари.'
# Failed to process ad: 'продаю iphone 12 pro 256 gb
# цена 1500 лари
# без повреждений, без замены деталей.
# в отличном состоянии.
# по всем вопросам и предложениям пишите в лс'
# Failed to process ad: 'продам переводчик, 100€ лимассол около пица mia'
# Failed to process ad: 'for sale, hp prodesk 400 g3 mt
# intel core i3-6100, 4gb ram, 450 gb hdd, windows 7 pro.
# used, very good condition.
# 90 euro. limassol'
# Failed to process ad: 'Распродажа
# Ткань бязь 120 г , состов 100% хлопок
# Цена 399р
# Размер пододеяльник 150х115см 1шт
#  Размер простыня  150х100см 1шт
# Размер: наволочки 60х40см 1шт
# Без выбора цвета
# Арт: 2Б-88 корпус А
# https://vk.com/id411325659'
# Failed to process ad: 'грузинские хинкали на заказ.  минимальный заказ от 20 штук 20 евро.  доставка бесплатная.  лимассол'
# Failed to process ad: 'продаю:
#
# кожаные ботинки zara, 40 размер, совершенно новенькие: покупала за 4,5к в москве, продаю за 100 лари.
#
# пишите!
#
# #тбилиси
# #авлабари'
# Failed to process ad: 'Распродажа
# Цена 350р
# Ткань прадо
# Размер: S,M
# Арт 2Г-77 корпус Б'
# Failed to process ad: 'женские часы daniel wellington, оригинал в идеальном состоянии. в комплекте 2 оригинальных кожаных ремешка, коричневый аля винтаж и черный. коробка и всякие бумажки в комплекте. 200 лари, мед. университет'
# Failed to process ad: 'Распродажа
# Пижама двойка
# Размер: 98-104-110-116-122
# Размерность: в размере
# Без выбора
# Цена: 200р
# Арт: 26-56
# https://vk.com/club179523720'
# Failed to process ad: 'продам одним лотом есть продукты которые вообще новые 25 лари'
# Failed to process ad: 'кресло-мешок ,,груша’’
# в отличном состоянии
# 20 €'
# Failed to process ad: 'Новая,облегчённая,качественная куртка,размер 54-56
# ...
# Failed to process ad: 'торг уместен. возможна скидка, если забираете несколько позиций.
# забрать можно в районе дидубе (парк киквидзе), либо яндекс доставкой (при сумме от 80 - отправлю за свой счет).
# !!! до вечера среды'
# Failed to process ad: 'боди bershka ⚡️
# s размер. вискоза с хлопком и эластаном. один раз носила.
#
# цена: 35 лари'
# Failed to process ad: 'Велосипедки
# Цена: 150руб
# Распродажа
# Ткань: рубчик
# Размеры 42-44-46-48-50-52
# Без выбора цвета
# Тц корпус А 2В-71'
# Failed to process ad: 'Куплю Телефоны: ИМЕННО ЭТИ МОДЕЛИ СНИЗУ ПЕРЕЧИСЛЕННЫЕ!!!
# - Можно полностью целые/рабочие или разбитые/с косяком на запчасти!
#
# • Honor 70 цвет не важен.
#
# • Samsung Note 20 Ultra цвет не важен.
#
# • Iphone от X до Iphone 14 pro max цвет не важен.
#
# • Samsung A52 цвет не важен.
#
# • Poco X3 pro цвет типо золотистый! (как на фото).
#
# •Huawei y6p 2019г цвет не важен.
#
# • Honor 9x цвет не важен.'
# Failed to process ad: 'стикеры русского алфавита на pc клавиатуру💻буквы - не стираются⌨️ есть на белую и чёрную клавиатуры. цена за штуку €5. бесплатная доставка по лимасолу.🚗'
# Failed to process ad: 'Новиночка сезона
# Этот комплект двойка поразит всех!
# Курточка с двухсторонней молнией и крутые штанишки
# Умопомрачительный образ для самых стильных!
# Цена: 1900₽
# Размеры: 54,56,58,60,62,64
# В размер
# Ткань - Двухнитка на флисе+Болонь на подкладке
# Подробнее на https://vk.com/wall488363770_21437'
# Failed to process ad: 'велосипед на планетарной втулке
# 3 скорости
# размер рамы 56
# 500 лари'
# Failed to process ad: 'Распродажа
# Органайзер для косметики
# Цена: 150р
# Арт: 9-82'
# Failed to process ad: 'iphone 14 pro, black, 256 gb. новый, нераспакован. 1100€'
# Failed to process ad: 'редкий комбинезон levis silver tab.
# размер s - по бирке. фит - оверсайз. мой рост 173, штаны и джинсы ношу 32 - мне велик.
# по факту думаю на рост 180
# и мужской 32-33 размер по талии, либо как у меня оверсайз
#
# унисекс
#
# состояние 8/10
# стоимость 250 лари
#
# самовывоз: ваке, ул. абашидзе 70 или перевод на bog и курьером за ваш счет
# для покупки пишите в лс
#
# больше вещей по ссылке в шапке профиля'
# Failed to process ad: 'Халаты великан,
# Ткань велсоф .
# Тёплый приятный,
# Размер 58-60-62-64-66-68-70
# Цена 1300 рублей,
# Подробнее на https://vk.com/wall488363770_24047'
# Failed to process ad: 'ободки ручной работы💞🌸
# для подробной информации пишите в личку.
# 1. цена - 30€
# 2. цена - 30€
# 3. цена - 15€
# 4. цена - 15€
# 5. цена - 3€
# 6. цена - 30€
# лимассол.'
# Failed to process ad: 'продам raspberry pi 4 на 4гб озу. в комплекте охлаждение и бп. цена 380 лари. так же отдельно есть переходник с мини hdmi на hdmi.'
# Failed to process ad: 'смартфон huawei honor 8x 4/64
# состояние отличное 150gel
# дидубе только самовывоз.'
# Failed to process ad: 'Продам Puma future rider
# Размер: 39
# Одевались несколько раз
# Цена: 2000 руб'
# Failed to process ad: 'продам кровать с матрасом 180*200 и двумя тумбами.
# габариты кровати 195*235
# цена 350€
# никосия'
# Failed to process ad: 'запечатанный
# дезодорант минерал) кристал.знаю что тут его фиг найдёшь.он новый в упаковке за 20 лари'
# Failed to process ad: 'Рубашка женская оверсайз. Хит в ноалм исполнении . Рубашка из смесового хлопка, качественный материал , белого цвета. Свободная и удлиненная женская рубашка с внутренними карманами, позволяет с легкостью скрыть недостатки фигуры
# Цена за штуку 500р по адресу 2A-54 корпус А
# Рынок садовод 8 926 723 07 20
# Подробнее на https://vk.com/wall488363770_21123'
# Failed to process ad: 'eko pedal bin 20l (superhome center)
# €20 limassol'
# Failed to process ad: 'Здравствуйте, продаю свой IPhone XS
# Есть трещина, АКБ новое, чехол в подарок, зарядка в комплекте, не работае фейс айди ( отошел шлейф).
# Обмен интересен на другой айфон с моей доплатой
# Цена 11000
# Срочно
# Г. Дмитров
#
# #БД_айфон #БД_телефон'
# Failed to process ad: 'штора в ванную новая, 180*180, лимассол, 2 евро'
# Failed to process ad: 'вело сумка kls на 20 литров. цена 60 лари.
# вместительная сумка-штаны на багажник велосипеда. сверху удобная резинка для крепления доп груза. внутри пластиковые подкладки помогают держать сумке форму. быстро снимается и надевается. ездил в основном на рынок с ней.
#
# также продаю багажник с катафотами (20 лар) и стрепы (10 лар).
#
# ⓜ️ марджанишвили'
# Failed to process ad: 'dvd плеер sony dvp-sr760h
# почти не использовался, состояние отличное — 15 евро'
# Failed to process ad: 'очень крутая юбка -карандаш  les copains italy размер 40-42 ,  60 лари'
# Failed to process ad: '#БНИ_ПродамБУ_Москва
# #БНИ_ПродамНовая_Москва
# #БНИ_Авито #БНИ_Почта #БНИ_Сберлогистика
# #БНИ_fizximik
#
# 70000 Aeon Trespass (все карты в протекторах, листы персонажей заламинированы+органайзеры)+ доп кубы+большое Дополнение Тайлы
# Углы коробки повреждены
# Дополнительные фото в лс.
# Возможен торг
#
# 41000 Frosthaven новый, запечатан.
# Также в комплекте соло-сценарии, наклейки, монеты. Углы коробки повреждены.
#
# 35000 Zombicide Galactus фигура+доп. Лот не бьется.
#
# 28000 Castle of Burgundy gameplay all-in. База+бонусы предзаказа в одной коробке
#
# 55000 Isofarian Guard. Как новая, коробка целая, пробная партия. Миниатюры в крутом заводском покрасе. 17 кг счастья
#
# 2700 Буллет. Bullet Anne. Промо, эксклюзив. В русском предзаказе не было и не будет.
#
# 27000 Гранд отель Австрия Делюкс Кикстартер издание: база с бонусами предзаказа+Биг бокс+доп. Внутри также апгрейд пак. Имеется пара коцок на Биг боксе.
#
# 10000 Эксклюзив Серп metal mechs. Новые, без пленки. Лимитированное издание. Металлические миниатюры.'
# Failed to process ad: 'iPhone 14 pro 128gb
# Новый пару месяцев использовался, без торга! Разбито стекло защитное, экран без защиты не носился и также всегда под чехлом! 90’000
# Самовывоз г. Дедовск'
# Failed to process ad: 'Штаны
# Цена 400руб
# Цена уп 350руб
# Распродажа
# Ткань хлопок
# Размер: 46-48-50-52-54
# Тц корпус Б 2д-09
# https://vk.com/mens.boutique'
# Failed to process ad: 'продам ноутбук 200 евро
#
# acer laptop, amd a12-9700p radeon r7 2.5 ghz, 4gb ram, 1 tb hdd'
# Failed to process ad: 'колонка jbl как новая, только не закрывается подставка для телефона🤷🏻‍♀️ работает от электричества. покупали за 150€, почти не пользовались. цена сейчас 70€. пила ларнака'
# Failed to process ad: 'отам бумагу для принтера под фото. глянцевая, для hp. 10 штучек, может у кого есть принтер и можно распечатать фотки. оригинальные'
# Failed to process ad: 'Коляска 2в1 и автокресло до 25кг за 3500тр.торг. только самовывоз,район ясенево'
# Failed to process ad: 'безворсовые салфетки для мастеров маникюра. 6 евро за упаковку. лимассол'
# Failed to process ad: 'алое
#
# в каждом горшке очень много саженцев если пересадить !
# лимассол
# снижение цены по 10 евро каждый !'
# Failed to process ad: 'Распродажа
# Цена: 199р штучно
# Размер: 36-37-38-38-39--39-40-41
# АРТ: 30-38'
# Failed to process ad: '🌹Новое поступление
#
# 🌹КПБ От Фирма,, FUANNA,,
# 🌹Ткань: ПОПЛИН
# 🌹Плотность ткани-140гр
#
# 🌹Размеры:
# 🌹1,5-спальный
# 🌹Пододеяльник 150*220см(1шт)
# 🌹Простыня          150*220см(1шт)
# 🌹Наволочки         70/70-(2шт)
# 🌹С выбором Цена 850р
#
# 🌹2х-спальный
# 🌹Пододеяльник 180*220см(1шт)
# 🌹Простыня          180*220см(1шт)
# 🌹Наволочки        70*70см(2шт)
# 🌹С выбором Цена-950р
#
# 🌹Евро:
# 🌹Пододеяльник 200*220см(1шт)
# 🌹Простыня         220*240см(1шт)
# 🌹Наволочки       50/70см(2шт)
# 🌹Наволочки       70/70см(2шт)
# 🌹С выбором Цена-1050р
#
# 🌹Семейный
# 🌹Пододеяльник 150*220см(2шт)
# 🌹Простыня         220*240см(1шт)
# 🌹Наволочки       50/70см(2шт)
# 🌹Наволочки      70/70см(2шт)
# 🌹С выбором Цена- 1150р
#
# Мы находимся торговый центр,Корпус А
# Второй этаж, Линия 2А-54
# Номер для связи 8 926 723 07 20 ватсап ☎️
# Подробнее на https://vk.com/wall488363770_21429'
# Failed to process ad: 'добрый день !
# продам книжечки. новые, не читанные.
#
# 1) архив буресвета путь королей 10€ (твёрдый переплёт)
# 2) 4 hour work week by tim ferris 10€
# 3) rise of the king by salvatore 5€
#
# пишите в личку 🙂'
# Failed to process ad: 'Продам детское ружье . Практически новое , ребенок толком не играл … предпочитает машинки чем оружие… водянист дома без дела. Друзья покупали в Детском мире. Такое новое с магазина стоит сейчас по скидке три тыс… продаю за 2000 тыс. Без дефектов все работает.'
# Failed to process ad: 'Распродажа
# Ткань: 85% хлопок 15% полиамид
# Рост: 86/92/98/104/110/116
# Цена: 100р
# Без выбора цвета
# Арт: 1-4-10 Корпус А'
# Failed to process ad: 'Размер манежа 1*1.5. Стоимость 650'
# Failed to process ad: 'Драцена - очень красивое комнатное растение. Абсолютно несложная в уходе. Быстро растет. Есть набухшие почки, из которых вырастут новые отростки, которые в дальнейшем создадут красивый кустик. Высота с горшком 33 см.
# #барахолка #барахолка@networksales #продам #объявления #товары #спб'
# Failed to process ad: 'Холодильник Саратов 1524м. Б/у, но в хорошем состоянии.
# Холодит и морозит очень хорошо, вилка советская, поэтому к ней стоит покупать переходник, который могу подарить, когда заберете холодильник
# 4000 руб.
# Только самовывоз 29-30 мая
# В нескольких минутах от м. Планерная'
# Failed to process ad: 'Голубоглазая Нефертити в поисках дома❗
# 🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟
# Она грациозна, умна, активна и жизнерадостна. Девушка ласковая, но самодостаточная, немного стеснительная, но быстро адаптируется. Хорошо уживается с другими кошками. Эта кошка не будет валяться в ногах у каждого встречного, но родным людям подарит свое большое кошачье сердце.
# Нефертити молода (2-3 года), здорова ( стерилизована). Лоток на 5 +.
# Звоните, пишите, а лучше приходите знакомиться!!!
# Пристраивается в семью с правом ненавязчивого отслеживания судьбы, взрослым и ответственным людям ,строго без самовыгула.
#
# ЛС https://vk.com/id108912551
#
# 8(953)971-13-28 Юлия (WhatsApp)
#
# #ПяловаЮлия_БелыйАнгел'
# Failed to process ad: 'продаю обувь:
# розовые сандали фирмы zaxy made in brazil ,пахнут чем-то сладеньким (по аналогу c брендом melissa,если знаете)
# купила месяц назад,наделе 1 раз,из-за беременности и отёчности не могу носить,по стельке 24 см- 70 лари
# белые босоножки турецкой фирмы fabrika,покупала и надевала на свадьбу,по стельке 24-24,5 см,каблук от пятки 7 см-50 лари
# черные босоножки на танкетке,американской фирмы soda,очень мягкие и лёгкие,ни разу не натерли,по стельке 24 см,высота каблука  указана на фото-50 лари.
#
# 📍забирать в дигоми,самовывоз/доставка или возможно у станции метро по договоренности.примерка возможна если приедете самостоятельно забирать.за дополнительными фото пишите в личку.'
# Failed to process ad: '1. Прихожая, в хорошем состоянии. 2500 руб.
# 2. Турник настенный, новый. 1000 руб.
# 3. Samsung HT-TXQ120. Сабвуфер, усилитель и колонки. В идеальном состоянии. 2000 руб.'
# Failed to process ad: 'denis_ozdemir нарушил правила чата и не сможет писать до 02.09.2023 17:52:12. правила чатов'
# Failed to process ad: '🖥️Монитор:Asus В хорошем состоянии 🖥️Диагональ:17 Разъемы VGA-DVl Цена 2000 быстрым торг'
# Failed to process ad: 'Продаю настольную игру "Особняки безумия". Купил совсем недавно. Фигурки и карточки на месте. Всё в отличном состоянии!
# 1. Изначальная цена + коробочки = 8500
# 2. Продам за 5500
# 3. Ближайшее метро, где вы можете забрать эту игру, станция Нижегородская. Если ваше местоположение недалеко от центра, я могу сам подъехать.
# Если нужны фотографии всего содержимого, пишите
# Оплатить можно переводом на Сберкарту'
# Failed to process ad: 'Series s, как новая, почти не пользовались, более 400 игр бесплатно по подписке, есть коробка и чек, второй геймпад новый, без геймпада 24000, с 2 геймпадами 29000, можно проверить у меня дома. На аккаунте гта 5, ведьмак 3, 3 части метро.
#
# #техника'
# Failed to process ad: 'TENDANCE лоферы женские.
# Лоферы 35 размера, оказались слегка велики, поэтому не очень удобно их носить. Очень мягкие и невесомые в носке. Бренд Tendance, France. Коробка, конечно же, присутствует.
# Цена: 5500₽'
# Failed to process ad: 'новый органайзер, сделанный из натуральных материалов , отлично подойдет для кухни или для хранения мелочей. ручная работа, ручки выполнены из натуральной кожи.
# размеры:
# длина 30 см
# ширина 10 см
# высота 5,5 см, а с учетом ручек 10 см
# 30 евро, лимассол
#
# так же смогу сделать на заказ по индивидуальным размерам и с выбором цвета.'
# Failed to process ad: 'надувные матрацы новые в упаковке, 60 евро за два, в магазине один стоит так, город ороклини'
# Failed to process ad: 'Пакеты для грудного молока, из 30 штук осталось больше 20. Отдам за шоколадку.'
# Failed to process ad: 'продаю новые куртку и флисовую кофту the north face. размер м, вещи новые, оригинальные, не подошли по размеру.
# куртка 180 лари, кофта 120 лари'
# Failed to process ad: 'macbook pro 13 m1 8gb 1tb ssd, perfect condition, eng/rus keyboard limassol, 960 euro'
# Failed to process ad: 'корсет для осанки
# 40 лари'
# Failed to process ad: 'Продается Cinema Display apple model a1081
# В хорошем состоянии ,не включается после сервисной диагностики сказали проблемы в блоке питания
# 2000
# Москва метро пражская'
# Failed to process ad: 'продам комплект тарелок 6 глубоких суповых, 3 плоские большие и 4 плоские маленькие.  на большой есть один скол. 5 евро. пиргос'
# Failed to process ad: 'книжки в хорошем состоянии, каждая по 2€, лимасол, район метро'
# Failed to process ad: 'цена 7€
# пафос, самовывоз
#
# мышка в рабочем состоянии, есть следы эксплуатации'
# Failed to process ad: 'Распродажа
# Джинсы МОМ
# Цена: 650р
# Ткань: Джинс Тянется
# Размер: 40-42-44-46-48-50
# АРТ: 2А-67 корпус Б
# https://vk.com/club153376802'
# Failed to process ad: 'ЛОСИНЫ ЖЕНСКИЕ ОСЕНЬ ВЕСНА .
# ОЧЕНЬ УДОБНЫЕ ДЛЯ ПРОГУЛКИ .
# ЗАНЯТИЕМ СПОРТА .
# КАЧЕСТВО ОЧЕНЬ ХОРОШОЕ
# НОВОЕ ПОСТУПЛЕНИЯ
# РАЗМЕРЫ :42:44:46:48:
# 50:52.54 56 58
# ЦЕНА :199₽'
# Failed to process ad: '2 прикроватных коврика, 71×50 см. оба за 10 евро. лимассол, самовывоз'
# Failed to process ad: 'sony a7r в отличном состоянии, использовалась как запасная камера. в комплекте с коробкой идут 3 аккумулятора, ремень и зарядка. 700 евро. лимассол, agia zoni.'
# Failed to process ad: 'samsung tv: qf6 uhd 4k 55’ for sale. excellent condition. with original box. 500€.limassol.'
# Failed to process ad: 'ковёр шкура коровья 90 евро , лимассол'
# Failed to process ad: 'Распродажа
# Рубашка
# Цена: 250р
# Ткань: Лайт
# Размер: 44-46-48-50-52-54
# Без выбора цвета
# АРТ: 24-119'
# Failed to process ad: 'всем привет!
# продам:
# 1. форма для выпечки кекса -5€
# 2. кулинарное кольцо d 16-30 -10€
# 3. формы для выпечки: d18 ( использовалась 1р.), d16(использовала часто, немного потерта после мыться) - 10€
#  4. стеклянная форма для запекания -5€
#  5. стаканы 2шт-3€
#  6. фруктовница - 3€
#  7. новогодние й набор: домовенок, поднос, подстилки «снежинки» на стол(3шт) - 10€
# лимассол'
# Failed to process ad: 'iphone 8 256гб - 300 лар (торг)
# батарея 🔋 75% - активно пользоваться - пол дня, нормально целый день.
# все функции работают исправно.
# все дефекты на фото.
# комплект: кабель+блок, черный чехол, адаптер lightning - mini jack для наушников.
#
# ⓜ️ марджанишвили'
# Failed to process ad: 'ковёр с высокими ворсинками 230 на 160 б/у чёрный в отличном состоянии 60 евро. самовывоз лимассол'
# Failed to process ad: 'Распродажа
# Носки детские
# Размер: 1 до 13лет
# Пачка 10пар
# Цена: 150р
# Без выбора
# Арт: 2г-57 корпус А'
# Failed to process ad: 'забронировали. продам измеритель давления + пульсометр. 20 лари. самовывоз из района сабуртало, между метро мед. университет и делиси.'
# Failed to process ad: 'Журнал
# ПРОЕКТ РОССИЯ № 88 - 89/2019 «Общественные интерьеры»
# #барахолка #барахолка@networksales #продам #объявления #товары #спб'
# Failed to process ad: 'массажёр, новый, использовали 2 раза. 15 евро, лимассол'
# Failed to process ad: 'Куртки женские весенние
# Новинка сезона
# Мы хотим что бы наши прекрасные дамы были всегда в тренде,и выглядели великолепно.
# Качество очень хорошое .
# Размеры : M(42-44)L(44/46):XL(48/50):2XL(50/52)3XL(52/54)
# Цена: 999 рублей
# Место :2В-84.Корпус. А
# Подробнее на https://vk.com/wall488363770_20954'
# Failed to process ad: 'Распродажа
# Цена: 450р шт
# Размер: 36 37 38 39 40
# Без выбора цвета
# Арт: 27-33'
# Failed to process ad: 'Распродажа
# Капсулы для стирки 40шт
# Цена: 350р
# Арт: 2д-27 корпус Б'
# Failed to process ad: 'Балдахин и бортики в детскую кроватку
# 2000т.р'
# Failed to process ad: '#БНИ_ПродамБу_Иркутск
# #БНИ_Сберлогистика
# #БНИ_Авито
# #БНИ_weiss
#
# City of spies. Estoril 1942
# 2000₽
#
# Отличное состояние, полный комплект'

# %%
import pickle as pkl
pkl.dump(labeled_data, open('labeled_data.pkl', 'wb'))

# %%
labeled_data.to_csv('add_labeled_data.csv')

# %%
labeled_data = pd.read_csv("final_markup.csv")
labeled_data.shape
# Out:
# (5001, 5)

# %%
labeled_data.head()
# Out:
#                                                    Text      WallId  PostId  \
# 5000  Распродажа \nКоллагеновый консилер от Enough\n...  -206817857   86686
# 5001  Цена: 150р\nРазмер : 80-86-92-98-104-110 рост\...  -206817857  112097
# 5002  #продаю в тбилиси focusrite scatlett 2i2. полн...  1332882905  439179
# 5003  Ботильоны Vagabond, натуральная кожа/мех, 39 р...   -48332904  713045
# 5004  Цена: 700р\nраспродажа \nРазмеры: 42,44,46,48,...  -206817857  120264
#
#      Source                                        GptResponse
# 5000     vk  {\n  "place": "Арт: 2-3-01 корпус Б",\n  "bund...
# 5001     vk  {\n  "place": "линия 28 павильон 65",\n  "bund...
# 5002     tg  {\n  "place": "Тбилиси",\n  "bundles": [\n    ...
# 5003     vk  {\n  "place": "Мелведково, Бибирево",\n  "bund...
# 5004     vk  {\n  "place": "тц корпус 2-2-14",\n  "bundles"...

# %%
labeled_data = pd.read_csv('labeled_data.csv')

# %%
from json.decoder import JSONDecodeError
parsed_gpt_labels = {
    "Text": [],
    "WallId": [],
    "PostId": [],
    "Source": [],
    "Title": [],
    "Price": [],
    "Currency": [],
    "Count": [],
}

failed_inds = []
empty_inds = []

for ind in tqdm(labeled_data.index):
    try:
        res = json.loads(labeled_data.loc[ind, "GptResponse"])
    except JSONDecodeError as e:
        failed_inds.append(ind)
        continue

    if "bundles" not in res:
        empty_inds.append(ind)

    for prod in res.get("bundles", []):
        for col in ("Text", "WallId", "PostId", "Source"):
            parsed_gpt_labels[col].append(labeled_data.loc[ind, col])
        parsed_gpt_labels["Title"].append(prod.get("name"))
        parsed_gpt_labels["Price"].append(prod.get("price"))
        parsed_gpt_labels["Currency"].append(prod.get("currency", "RUB"))
        parsed_gpt_labels["Count"].append(prod.get("quantity", 1))

gpt_labels_df = pd.DataFrame(parsed_gpt_labels)
failed_to_parse_df = labeled_data.loc[failed_inds, :].copy()
no_bundles_df = labeled_data.loc[empty_inds, :].copy()

gpt_labels_df.head()
# Out:
#   0%|          | 0/3591 [00:00<?, ?it/s]
#                                                 Text      WallId  PostId  \
# 0  Распродажа \nКоллагеновый консилер от Enough\n...  -206817857   86686
# 1  #продаю в тбилиси focusrite scatlett 2i2. полн...  1332882905  439179
# 2  Ботильоны Vagabond, натуральная кожа/мех, 39 р...   -48332904  713045
# 3  Цена: 700р\nраспродажа \nРазмеры: 42,44,46,48,...  -206817857  120264
# 4  продам кухонный стол. стол удобный, основатель...  1121942433  699812
#
#   Source                                              Title Price Currency  \
# 0     vk                    Коллагеновый консилер от Enough    80      RUB
# 1     tg                             focusrite scatlett 2i2   190        ₾
# 2     vk  Ботильоны Vagabond, натуральная кожа/мех, разм...  5000      RUB
# 3     vk                                    флисовая одежда   700      RUB
# 4     tg                            кухонный стол и 4 стула   150      EUR
#
#   Count
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
# !mkdir data
# Out:
# mkdir: cannot create directory ‘data’: File exists

# %%
print(gpt_labels_df.shape)
gpt_labels_df.to_csv("data/add_labeled_5k.csv", index=False)
# Out:
# (5153, 8)

# %%
print(failed_to_parse_df.shape)
failed_to_parse_df.to_csv("data/invalid_jsons.csv", index=False)
# Out:
# (2, 5)

# %%
print(no_bundles_df.shape)
gpt_labels_df.to_csv("data/empty_ads.csv", index=False)
# Out:
# (244, 5)

# %%
gpt_labels_df.shape
# Out:
# (6984, 8)

# %%
gpt_labels_df.isna().sum()
# Out:
# Text         0
# WallId       0
# PostId       0
# Source       0
# Title        0
# Price       79
# Currency     0
# Count        0
# dtype: int64
