# %%
import pandas as pd

# %%
df = pd.read_csv('labeled_15k.csv')
len(df)
# Out:
# 19214

# %%
df
# Out:
#        Unnamed: 0                                               Text  \
# 0               0  1. монитор, 250 лари\n2. мольберт, 50 лари\n3....
# 1               1  #БНИ_ПродамБУ_Москва\n#БНИ_ПродамНовая_Москва\...
# 2               2  Продам стульчик для кормления Happy baby. В хо...
# 3               3  Продаю компьютер Цена 55000 Все почти новое ,е...
# 4               4  Новинка сезона \nКачество очень хорошее \nЦена...
# ...           ...                                                ...
# 19209       19209  ЧАСТЬ 5 (5)\n37) кофта суприм 250р\n38) свитер...
# 19210       19210  ЧАСТЬ 5 (5)\n37) кофта суприм 250р\n38) свитер...
# 19211       19211  ЧАСТЬ 5 (5)\n37) кофта суприм 250р\n38) свитер...
# 19212       19212  Все тот же матрас 70х200 в отличном состоянии....
# 19213       19213  Распродажа\nСито для муки круглое 213 мм\nЦена...
#
#            WallId  PostId Source                                      Title  \
# 0      1332882905  686748     tg     рюкзак, 40 литров, идеальное состояние
# 1      -114967596  592027     vk        Street Fighter (база, стретчи, доп)
# 2       -82544098  661957     vk          Стульчик для кормления Happy baby
# 3       -90442795  353383     vk  Компьютер с комплектующими и аксессуарами
# 4      -192083416   15466     vk                             Новинка сезона
# ...           ...     ...    ...                                        ...
# 19209  -177461486   45032     vk                               свитер синий
# 19210  -177461486   45032     vk                             свитер розовый
# 19211  -177461486   45032     vk                                сапоги asos
# 19212  -177461486   51650     vk         Матрас 70х200 в отличном состоянии
# 19213  -203393330  128851     vk               Сито для муки круглое 213 мм
#
#        Price Currency Count Label_gpt  \
# 0        100     лари     1     valid
# 1      26000      RUB     1     valid
# 2       3000      RUB     1     valid
# 3      55000      RUB     1     valid
# 4       2000      RUB     1   invalid
# ...      ...      ...   ...       ...
# 19209    250      RUB     1     valid
# 19210    400      RUB     1     valid
# 19211    900      RUB     1     valid
# 19212   3000      RUB     1     valid
# 19213    150      RUB     1     valid
#
#                                              Comment_gpt
# 0      The offer includes a backpack bundle that matc...
# 1      The offer clearly describes the bundle's conte...
# 2      The offer clearly describes a single feeding c...
# 3      The offer clearly describes a computer with co...
# 4      The OFFER lacks detailed product information, ...
# ...                                                  ...
# 19209  The offer clearly describes the bundle includi...
# 19210  The offer matches the bundle description accur...
# 19211  The offer matches the described bundle with su...
# 19212  The description directly matches the offer wit...
# 19213  The offer clearly describes a single bundle wi...
#
# [19214 rows x 11 columns]

# %%
df10 = pd.read_csv('labeled_and_validated_10k.csv')

# %%
df10
# Out:
#        Unnamed: 0                                               Text  \
# 0               0  1. монитор, 250 лари\n2. мольберт, 50 лари\n3....
# 1               1  #БНИ_ПродамБУ_Москва\n#БНИ_ПродамНовая_Москва\...
# 2               2  Продам стульчик для кормления Happy baby. В хо...
# 3               3  Продаю компьютер Цена 55000 Все почти новое ,е...
# 4               4  Новинка сезона \nКачество очень хорошее \nЦена...
# ...           ...                                                ...
# 14056       14056  Распродажа\nЦЕНА.400р\nРАЗМЕРЫ: 54/56/58/60\nР...
# 14057       14057  #БНИ_ПродамБУ_Москва \n#БНИ_СДЭК \n#БНИ_Авито ...
# 14058       14058  Продаю;Ботинки 34р,1000р.Ботинки утеплённые 34...
# 14059       14059  Продам школьные платья, состояние отличное. Ро...
# 14060       14060  Картина готовая по номерам, за каждую 350 рубл...
#
#            WallId  PostId Source  \
# 0      1332882905  686748     tg
# 1      -114967596  592027     vk
# 2       -82544098  661957     vk
# 3       -90442795  353383     vk
# 4      -192083416   15466     vk
# ...           ...     ...    ...
# 14056  -203393330  142623     vk
# 14057  -114967596  573450     vk
# 14058   -82544098  642652     vk
# 14059   -90442795  353666     vk
# 14060   -82544098  645337     vk
#
#                                                   Title  Price Currency Count  \
# 0                рюкзак, 40 литров, идеальное состояние    100     лари     1
# 1                   Street Fighter (база, стретчи, доп)  26000      RUB     1
# 2                     Стульчик для кормления Happy baby   3000      RUB     1
# 3             Компьютер с комплектующими и аксессуарами  55000      RUB     1
# 4                                        Новинка сезона   2000      RUB     1
# ...                                                 ...    ...      ...   ...
# 14056                                 Распродажа одежды    400      RUB     1
# 14057   Пробуждение Медведя с дополнением Тяжелые танки   3500      RUB     1
# 14058                     Куртка демисезонная 92 размер    600      RUB     1
# 14059                     Школьные платья, рост 122-140    500      RUB     1
# 14060  Картина готовая по номерам, постер для интерьера    350      RUB     1
#
#       Label_gpt                                        Comment_gpt
# 0         valid  The offer includes a backpack bundle that matc...
# 1         valid  The offer clearly describes the bundle's conte...
# 2         valid  The offer clearly describes a single feeding c...
# 3         valid  The offer clearly describes a computer with co...
# 4       invalid  The OFFER lacks detailed product information, ...
# ...         ...                                                ...
# 14056   invalid  The offer lacks specific details about the ite...
# 14057     valid  The offer clearly includes the described bundl...
# 14058     valid  The OFFER clearly states the product matching ...
# 14059   invalid  The OFFER lacks specific details about the bun...
# 14060     valid  The offer provides clear details about the sin...
#
# [14061 rows x 11 columns]

# %%
df = df[df.Label_gpt == 'valid']
len(df)
# Out:
# 16098
